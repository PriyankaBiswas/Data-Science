# %%
import tweepy
import os, sys, csv, time
import pandas as pd
import numpy as np

# %%
# Twitter credentials

consumer_key = 'es8zMLQOd3TGfwwEa5EQ8bF51'
consumer_secret = 'Nk7SP5zuhFBPre7hFDiOIUyU2mYzKC5fVOhkFyVu1soOCEtexr'
access_key = '424438626-l0Bic8MCWwsvhQvFr8Ickcfl8CqVNhIdgf1DRGfh'
access_secret = 'hNyNJ60jnhT5hDG7sSHwQbX35M5TefKY8SJrrKAHjuwLc'

# %%
# Tweepy authorization and api initiation

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)  #keeps waiting instead of giving error message

# %%
# Get actual tweets

#DT_tweet = api.get_user('realDonaldTrump')._json
#dt = api.search(tweet_mode="extended", max_id=1, q = 'verified', count=10) 

#def print_tweet(tweet):
#    print(tweet.user.id, tweet.user.id_str, tweet.user.screen_name, tweet.user.location, tweet.user.description, 
#                             tweet.user.url, tweet.user.followers_count, tweet.user.friends_count, tweet.user.listed_count,
#                             tweet.user.created_at, tweet.user.favourites_count, tweet.user.verified,
#                             tweet.user.statuses_count, tweet.user.lang, tweet.user.default_profile)
#                             #tweet.user.default_profile_image, tweet.user.has_extended_profile, tweet.user.name))
#
#tweet=dt[3]
#print_tweet(tweet)

# checking if the screen_names are verified by twitter
#for tweet in np.arange(10):
#    print(dt[tweet].user.screen_name, dt[tweet].user.verified)

# %%
## Run this in a separate notebook as this pauses the notebook when api user limit exceeds. 

#verified_screen_names = []
#for user in tweepy.Cursor(api.friends, screen_name="verified").items():  #'friends are the accounts that @verified follows and are verified'
#    verified_screen_names.append(user.screen_name)
#    print('friend: ' + user.screen_name, user.verified)
#

# %%
search_text = "#IVoted"
search_number = 2
l1 = []
l2 = []
search_result = api.search_users(search_text, count=30)
for i in search_result:
    ivoted_users.bot.append(i.name),
    l2.append(i.created_at)
    #print(len(search_result), 'names',i.name, 's_name:',i.screen_name, 'counts:',i.followers_count, i.friends_count, i.statuses_count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-4e42c784bd86> in <module>()
#       5 search_result = api.search_users(search_text, count=30)
#       6 for i in search_result:
# ----> 7     ivoted_users.bot.append(i.name),
#       8     l2.append(i.created_at)
#       9     #print(len(search_result), 'names',i.name, 's_name:',i.screen_name, 'counts:',i.followers_count, i.friends_count, i.statuses_count)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in append(self, to_append, ignore_index, verify_integrity)
#    2154             to_concat = [self, to_append]
#    2155         return concat(to_concat, ignore_index=ignore_index,
# -> 2156                       verify_integrity=verify_integrity)
#    2157
#    2158     def _binop(self, other, func, level=None, fill_value=None):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     284                        ' only pd.Series, pd.DataFrame, and pd.Panel'
#     285                        ' (deprecated) objs are valid'.format(type(obj)))
# --> 286                 raise TypeError(msg)
#     287
#     288             # consolidate
#
# TypeError: cannot concatenate object of type "<class 'str'>"; only pd.Series, pd.DataFrame, and pd.Panel (deprecated) objs are valid

# %%
ivoted_users = pd.DataFrame(columns=cols)
ivoted_users
# Out:
# Empty DataFrame
# Columns: [bot, created_at, default_profile, default_profile_image, description, favourites_count, followers_count, friends_count, has_extended_profile, id, id_str, lang, listed_count, location, name, screen_name, status, statuses_count, url, verified]
# Index: []

# %%
cols = ['bot', 'created_at', 'default_profile', 'default_profile_image',
       'description', 'favourites_count', 'followers_count', 'friends_count',
       'has_extended_profile', 'id', 'id_str', 'lang', 'listed_count',
       'location', 'name', 'screen_name', 'status', 'statuses_count', 'url',
       'verified']

ivoted_users = pd.DataFrame(columns=cols)

# %%
bot = []
created_at = []
default_profile =[]
default_profile_image = []
description = []
favourites_count = []
followers_count= []
friends_count= []
has_extended_profile = []
ids = []
id_str = []
lang = [] 
listed_count =[]
location = []
name = []
screen_name = []
status = []
statuses_count = []
url = []
verified = []

# %%
counter = 0
for tweet in tweepy.Cursor(api.search, q="IVoted", 
                           #since="2014-02-14", #until="2014-02-15", 
                           lang="en").items(10000):

    print("gathering user...",counter)
    created_at.append(tweet.author.created_at),
    default_profile.append(tweet.author.default_profile),
    default_profile_image.append(tweet.author.default_profile_image),
    description.append(tweet.author.description),
    favourites_count.append(tweet.author.favourites_count),
    followers_count.append(tweet.author.followers_count),
    friends_count.append(tweet.author.friends_count),
    #ivoted_users['has_extended_profile'] = tweet.author.has_extended_profile,
    ids.append(tweet.author.id),
    id_str.append(tweet.author.id_str),
    lang.append(tweet.author.lang),
    listed_count.append(tweet.author.listed_count),
    location.append(tweet.author.location), 
    name.append(tweet.author.name),
    screen_name.append(tweet.author.screen_name),
    #ivoted_users['status'] = tweet.author.statuses_count
    statuses_count.append(tweet.author.statuses_count),
    url.append(tweet.author.url),
    verified.append(tweet.author.verified)
    counter +=1
    
#csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.screen_name])
# Out:
# gathering user... 0
# gathering user... 1
# gathering user... 2
# gathering user... 3
# gathering user... 4
# gathering user... 5
# gathering user... 6
# gathering user... 7
# gathering user... 8
# gathering user... 9
# gathering user... 10
# gathering user... 11
# gathering user... 12
# gathering user... 13
# gathering user... 14
# gathering user... 15
# gathering user... 16
# gathering user... 17
# gathering user... 18
# gathering user... 19
# gathering user... 20
# gathering user... 21
# gathering user... 22
# gathering user... 23
# gathering user... 24
# gathering user... 25
# gathering user... 26
# gathering user... 27
# gathering user... 28
# gathering user... 29
# gathering user... 30
# gathering user... 31
# gathering user... 32
# gathering user... 33
# gathering user... 34
# gathering user... 35
# gathering user... 36
# gathering user... 37
# gathering user... 38
# gathering user... 39
# gathering user... 40
# gathering user... 41
# gathering user... 42
# gathering user... 43
# gathering user... 44
# gathering user... 45
# gathering user... 46
# gathering user... 47
# gathering user... 48
# gathering user... 49
# gathering user... 50
# gathering user... 51
# gathering user... 52
# gathering user... 53
# gathering user... 54
# gathering user... 55
# gathering user... 56
# gathering user... 57
# gathering user... 58
# gathering user... 59
# gathering user... 60
# gathering user... 61
# gathering user... 62
# gathering user... 63
# gathering user... 64
# gathering user... 65
# gathering user... 66
# gathering user... 67
# gathering user... 68
# gathering user... 69
# gathering user... 70
# gathering user... 71
# gathering user... 72
# gathering user... 73
# gathering user... 74
# gathering user... 75
# gathering user... 76
# gathering user... 77
# gathering user... 78
# gathering user... 79
# gathering user... 80
# gathering user... 81
# gathering user... 82
# gathering user... 83
# gathering user... 84
# gathering user... 85
# gathering user... 86
# gathering user... 87
# gathering user... 88
# gathering user... 89
# gathering user... 90
# gathering user... 91
# gathering user... 92
# gathering user... 93
# gathering user... 94
# gathering user... 95
# gathering user... 96
# gathering user... 97
# gathering user... 98
# gathering user... 99
# gathering user... 100
# gathering user... 101
# gathering user... 102
# gathering user... 103
# gathering user... 104
# gathering user... 105
# gathering user... 106
# gathering user... 107
# gathering user... 108
# gathering user... 109
# gathering user... 110
# gathering user... 111
# gathering user... 112
# gathering user... 113
# gathering user... 114
# gathering user... 115
# gathering user... 116
# gathering user... 117
# gathering user... 118
# gathering user... 119
# gathering user... 120
# gathering user... 121
# gathering user... 122
# gathering user... 123
# gathering user... 124
# gathering user... 125
# gathering user... 126
# gathering user... 127
# gathering user... 128
# gathering user... 129
# gathering user... 130
# gathering user... 131
# gathering user... 132
# gathering user... 133
# gathering user... 134
# gathering user... 135
# gathering user... 136
# gathering user... 137
# gathering user... 138
# gathering user... 139
# gathering user... 140
# gathering user... 141
# gathering user... 142
# gathering user... 143
# gathering user... 144
# gathering user... 145
# gathering user... 146
# gathering user... 147
# gathering user... 148
# gathering user... 149
# gathering user... 150
# gathering user... 151
# gathering user... 152
# gathering user... 153
# gathering user... 154
# gathering user... 155
# gathering user... 156
# gathering user... 157
# gathering user... 158
# gathering user... 159
# gathering user... 160
# gathering user... 161
# gathering user... 162
# gathering user... 163
# gathering user... 164
# gathering user... 165
# gathering user... 166
# gathering user... 167
# gathering user... 168
# gathering user... 169
# gathering user... 170
# gathering user... 171
# gathering user... 172
# gathering user... 173
# gathering user... 174
# gathering user... 175
# gathering user... 176
# gathering user... 177
# gathering user... 178
# gathering user... 179
# gathering user... 180
# gathering user... 181
# gathering user... 182
# gathering user... 183
# gathering user... 184
# gathering user... 185
# gathering user... 186
# gathering user... 187
# gathering user... 188
# gathering user... 189
# gathering user... 190
# gathering user... 191
# gathering user... 192
# gathering user... 193
# gathering user... 194
# gathering user... 195
# gathering user... 196
# gathering user... 197
# gathering user... 198
# gathering user... 199
# gathering user... 200
# gathering user... 201
# gathering user... 202
# gathering user... 203
# gathering user... 204
# gathering user... 205
# gathering user... 206
# gathering user... 207
# gathering user... 208
# gathering user... 209
# gathering user... 210
# gathering user... 211
# gathering user... 212
# gathering user... 213
# gathering user... 214
# gathering user... 215
# gathering user... 216
# gathering user... 217
# gathering user... 218
# gathering user... 219
# gathering user... 220
# gathering user... 221
# gathering user... 222
# gathering user... 223
# gathering user... 224
# gathering user... 225
# gathering user... 226
# gathering user... 227
# gathering user... 228
# gathering user... 229
# gathering user... 230
# gathering user... 231
# gathering user... 232
# gathering user... 233
# gathering user... 234
# gathering user... 235
# gathering user... 236
# gathering user... 237
# gathering user... 238
# gathering user... 239
# gathering user... 240
# gathering user... 241
# gathering user... 242
# gathering user... 243
# gathering user... 244
# gathering user... 245
# gathering user... 246
# gathering user... 247
# gathering user... 248
# gathering user... 249
# gathering user... 250
# gathering user... 251
# gathering user... 252
# gathering user... 253
# gathering user... 254
# gathering user... 255
# gathering user... 256
# gathering user... 257
# gathering user... 258
# gathering user... 259
# gathering user... 260
# gathering user... 261
# gathering user... 262
# gathering user... 263
# gathering user... 264
# gathering user... 265
# gathering user... 266
# gathering user... 267
# gathering user... 268
# gathering user... 269
# gathering user... 270
# gathering user... 271
# gathering user... 272
# gathering user... 273
# gathering user... 274
# gathering user... 275
# gathering user... 276
# gathering user... 277
# gathering user... 278
# gathering user... 279
# gathering user... 280
# gathering user... 281
# gathering user... 282
# gathering user... 283
# gathering user... 284
# gathering user... 285
# gathering user... 286
# gathering user... 287
# gathering user... 288
# gathering user... 289
# gathering user... 290
# gathering user... 291
# gathering user... 292
# gathering user... 293
# gathering user... 294
# gathering user... 295
# gathering user... 296
# gathering user... 297
# gathering user... 298
# gathering user... 299
# gathering user... 300
# gathering user... 301
# gathering user... 302
# gathering user... 303
# gathering user... 304
# gathering user... 305
# gathering user... 306
# gathering user... 307
# gathering user... 308
# gathering user... 309
# gathering user... 310
# gathering user... 311
# gathering user... 312
# gathering user... 313
# gathering user... 314
# gathering user... 315
# gathering user... 316
# gathering user... 317
# gathering user... 318
# gathering user... 319
# gathering user... 320
# gathering user... 321
# gathering user... 322
# gathering user... 323
# gathering user... 324
# gathering user... 325
# gathering user... 326
# gathering user... 327
# gathering user... 328
# gathering user... 329
# gathering user... 330
# gathering user... 331
# gathering user... 332
# gathering user... 333
# gathering user... 334
# gathering user... 335
# gathering user... 336
# gathering user... 337
# gathering user... 338
# gathering user... 339
# gathering user... 340
# gathering user... 341
# gathering user... 342
# gathering user... 343
# gathering user... 344
# gathering user... 345
# gathering user... 346
# gathering user... 347
# gathering user... 348
# gathering user... 349
# gathering user... 350
# gathering user... 351
# gathering user... 352
# gathering user... 353
# gathering user... 354
# gathering user... 355
# gathering user... 356
# gathering user... 357
# gathering user... 358
# gathering user... 359
# gathering user... 360
# gathering user... 361
# gathering user... 362
# gathering user... 363
# gathering user... 364
# gathering user... 365
# gathering user... 366
# gathering user... 367
# gathering user... 368
# gathering user... 369
# gathering user... 370
# gathering user... 371
# gathering user... 372
# gathering user... 373
# gathering user... 374
# gathering user... 375
# gathering user... 376
# gathering user... 377
# gathering user... 378
# gathering user... 379
# gathering user... 380
# gathering user... 381
# gathering user... 382
# gathering user... 383
# gathering user... 384
# gathering user... 385
# gathering user... 386
# gathering user... 387
# gathering user... 388
# gathering user... 389
# gathering user... 390
# gathering user... 391
# gathering user... 392
# gathering user... 393
# gathering user... 394
# gathering user... 395
# gathering user... 396
# gathering user... 397
# gathering user... 398
# gathering user... 399
# gathering user... 400
# gathering user... 401
# gathering user... 402
# gathering user... 403
# gathering user... 404
# gathering user... 405
# gathering user... 406
# gathering user... 407
# gathering user... 408
# gathering user... 409
# gathering user... 410
# gathering user... 411
# gathering user... 412
# gathering user... 413
# gathering user... 414
# gathering user... 415
# gathering user... 416
# gathering user... 417
# gathering user... 418
# gathering user... 419
# gathering user... 420
# gathering user... 421
# gathering user... 422
# gathering user... 423
# gathering user... 424
# gathering user... 425
# gathering user... 426
# gathering user... 427
# gathering user... 428
# gathering user... 429
# gathering user... 430
# gathering user... 431
# gathering user... 432
# gathering user... 433
# gathering user... 434
# gathering user... 435
# gathering user... 436
# gathering user... 437
# gathering user... 438
# gathering user... 439
# gathering user... 440
# gathering user... 441
# gathering user... 442
# gathering user... 443
# gathering user... 444
# gathering user... 445
# gathering user... 446
# gathering user... 447
# gathering user... 448
# gathering user... 449
# gathering user... 450
# gathering user... 451
# gathering user... 452
# gathering user... 453
# gathering user... 454
# gathering user... 455
# gathering user... 456
# gathering user... 457
# gathering user... 458
# gathering user... 459
# gathering user... 460
# gathering user... 461
# gathering user... 462
# gathering user... 463
# gathering user... 464
# gathering user... 465
# gathering user... 466
# gathering user... 467
# gathering user... 468
# gathering user... 469
# gathering user... 470
# gathering user... 471
# gathering user... 472
# gathering user... 473
# gathering user... 474
# gathering user... 475
# gathering user... 476
# gathering user... 477
# gathering user... 478
# gathering user... 479
# gathering user... 480
# gathering user... 481
# gathering user... 482
# gathering user... 483
# gathering user... 484
# gathering user... 485
# gathering user... 486
# gathering user... 487
# gathering user... 488
# gathering user... 489
# gathering user... 490
# gathering user... 491
# gathering user... 492
# gathering user... 493
# gathering user... 494
# gathering user... 495
# gathering user... 496
# gathering user... 497
# gathering user... 498
# gathering user... 499
# gathering user... 500
# gathering user... 501
# gathering user... 502
# gathering user... 503
# gathering user... 504
# gathering user... 505
# gathering user... 506
# gathering user... 507
# gathering user... 508
# gathering user... 509
# gathering user... 510
# gathering user... 511
# gathering user... 512
# gathering user... 513
# gathering user... 514
# gathering user... 515
# gathering user... 516
# gathering user... 517
# gathering user... 518
# gathering user... 519
# gathering user... 520
# gathering user... 521
# gathering user... 522
# gathering user... 523
# gathering user... 524
# gathering user... 525
# gathering user... 526
# gathering user... 527
# gathering user... 528
# gathering user... 529
# gathering user... 530
# gathering user... 531
# gathering user... 532
# gathering user... 533
# gathering user... 534
# gathering user... 535
# gathering user... 536
# gathering user... 537
# gathering user... 538
# gathering user... 539
# gathering user... 540
# gathering user... 541
# gathering user... 542
# gathering user... 543
# gathering user... 544
# gathering user... 545
# gathering user... 546
# gathering user... 547
# gathering user... 548
# gathering user... 549
# gathering user... 550
# gathering user... 551
# gathering user... 552
# gathering user... 553
# gathering user... 554
# gathering user... 555
# gathering user... 556
# gathering user... 557
# gathering user... 558
# gathering user... 559
# gathering user... 560
# gathering user... 561
# gathering user... 562
# gathering user... 563
# gathering user... 564
# gathering user... 565
# gathering user... 566
# gathering user... 567
# gathering user... 568
# gathering user... 569
# gathering user... 570
# gathering user... 571
# gathering user... 572
# gathering user... 573
# gathering user... 574
# gathering user... 575
# gathering user... 576
# gathering user... 577
# gathering user... 578
# gathering user... 579
# gathering user... 580
# gathering user... 581
# gathering user... 582
# gathering user... 583
# gathering user... 584
# gathering user... 585
# gathering user... 586
# gathering user... 587
# gathering user... 588
# gathering user... 589
# gathering user... 590
# gathering user... 591
# gathering user... 592
# gathering user... 593
# gathering user... 594
# gathering user... 595
# gathering user... 596
# gathering user... 597
# gathering user... 598
# gathering user... 599
# gathering user... 600
# gathering user... 601
# gathering user... 602
# gathering user... 603
# gathering user... 604
# gathering user... 605
# gathering user... 606
# gathering user... 607
# gathering user... 608
# gathering user... 609
# gathering user... 610
# gathering user... 611
# gathering user... 612
# gathering user... 613
# gathering user... 614
# gathering user... 615
# gathering user... 616
# gathering user... 617
# gathering user... 618
# gathering user... 619
# gathering user... 620
# gathering user... 621
# gathering user... 622
# gathering user... 623
# gathering user... 624
# gathering user... 625
# gathering user... 626
# gathering user... 627
# gathering user... 628
# gathering user... 629
# gathering user... 630
# gathering user... 631
# gathering user... 632
# gathering user... 633
# gathering user... 634
# gathering user... 635
# gathering user... 636
# gathering user... 637
# gathering user... 638
# gathering user... 639
# gathering user... 640
# gathering user... 641
# gathering user... 642
# gathering user... 643
# gathering user... 644
# gathering user... 645
# gathering user... 646
# gathering user... 647
# gathering user... 648
# gathering user... 649
# gathering user... 650
# gathering user... 651
# gathering user... 652
# gathering user... 653
# gathering user... 654
# gathering user... 655
# gathering user... 656
# gathering user... 657
# gathering user... 658
# gathering user... 659
# gathering user... 660
# gathering user... 661
# gathering user... 662
# gathering user... 663
# gathering user... 664
# gathering user... 665
# gathering user... 666
# gathering user... 667
# gathering user... 668
# gathering user... 669
# gathering user... 670
# gathering user... 671
# gathering user... 672
# gathering user... 673
# gathering user... 674
# gathering user... 675
# gathering user... 676
# gathering user... 677
# gathering user... 678
# gathering user... 679
# gathering user... 680
# gathering user... 681
# gathering user... 682
# gathering user... 683
# gathering user... 684
# gathering user... 685
# gathering user... 686
# gathering user... 687
# gathering user... 688
# gathering user... 689
# gathering user... 690
# gathering user... 691
# gathering user... 692
# gathering user... 693
# gathering user... 694
# gathering user... 695
# gathering user... 696
# gathering user... 697
# gathering user... 698
# gathering user... 699
# gathering user... 700
# gathering user... 701
# gathering user... 702
# gathering user... 703
# gathering user... 704
# gathering user... 705
# gathering user... 706
# gathering user... 707
# gathering user... 708
# gathering user... 709
# gathering user... 710
# gathering user... 711
# gathering user... 712
# gathering user... 713
# gathering user... 714
# gathering user... 715
# gathering user... 716
# gathering user... 717
# gathering user... 718
# gathering user... 719
# gathering user... 720
# gathering user... 721
# gathering user... 722
# gathering user... 723
# gathering user... 724
# gathering user... 725
# gathering user... 726
# gathering user... 727
# gathering user... 728
# gathering user... 729
# gathering user... 730
# gathering user... 731
# gathering user... 732
# gathering user... 733
# gathering user... 734
# gathering user... 735
# gathering user... 736
# gathering user... 737
# gathering user... 738
# gathering user... 739
# gathering user... 740
# gathering user... 741
# gathering user... 742
# gathering user... 743
# gathering user... 744
# gathering user... 745
# gathering user... 746
# gathering user... 747
# gathering user... 748
# gathering user... 749
# gathering user... 750
# gathering user... 751
# gathering user... 752
# gathering user... 753
# gathering user... 754
# gathering user... 755
# gathering user... 756
# gathering user... 757
# gathering user... 758
# gathering user... 759
# gathering user... 760
# gathering user... 761
# gathering user... 762
# gathering user... 763
# gathering user... 764
# gathering user... 765
# gathering user... 766
# gathering user... 767
# gathering user... 768
# gathering user... 769
# gathering user... 770
# gathering user... 771
# gathering user... 772
# gathering user... 773
# gathering user... 774
# gathering user... 775
# gathering user... 776
# gathering user... 777
# gathering user... 778
# gathering user... 779
# gathering user... 780
# gathering user... 781
# gathering user... 782
# gathering user... 783
# gathering user... 784
# gathering user... 785
# gathering user... 786
# gathering user... 787
# gathering user... 788
# gathering user... 789
# gathering user... 790
# gathering user... 791
# gathering user... 792
# gathering user... 793
# gathering user... 794
# gathering user... 795
# gathering user... 796
# gathering user... 797
# gathering user... 798
# gathering user... 799
# gathering user... 800
# gathering user... 801
# gathering user... 802
# gathering user... 803
# gathering user... 804
# gathering user... 805
# gathering user... 806
# gathering user... 807
# gathering user... 808
# gathering user... 809
# gathering user... 810
# gathering user... 811
# gathering user... 812
# gathering user... 813
# gathering user... 814
# gathering user... 815
# gathering user... 816
# gathering user... 817
# gathering user... 818
# gathering user... 819
# gathering user... 820
# gathering user... 821
# gathering user... 822
# gathering user... 823
# gathering user... 824
# gathering user... 825
# gathering user... 826
# gathering user... 827
# gathering user... 828
# gathering user... 829
# gathering user... 830
# gathering user... 831
# gathering user... 832
# gathering user... 833
# gathering user... 834
# gathering user... 835
# gathering user... 836
# gathering user... 837
# gathering user... 838
# gathering user... 839
# gathering user... 840
# gathering user... 841
# gathering user... 842
# gathering user... 843
# gathering user... 844
# gathering user... 845
# gathering user... 846
# gathering user... 847
# gathering user... 848
# gathering user... 849
# gathering user... 850
# gathering user... 851
# gathering user... 852
# gathering user... 853
# gathering user... 854
# gathering user... 855
# gathering user... 856
# gathering user... 857
# gathering user... 858
# gathering user... 859
# gathering user... 860
# gathering user... 861
# gathering user... 862
# gathering user... 863
# gathering user... 864
# gathering user... 865
# gathering user... 866
# gathering user... 867
# gathering user... 868
# gathering user... 869
# gathering user... 870
# gathering user... 871
# gathering user... 872
# gathering user... 873
# gathering user... 874
# gathering user... 875
# gathering user... 876
# gathering user... 877
# gathering user... 878
# gathering user... 879
# gathering user... 880
# gathering user... 881
# gathering user... 882
# gathering user... 883
# gathering user... 884
# gathering user... 885
# gathering user... 886
# gathering user... 887
# gathering user... 888
# gathering user... 889
# gathering user... 890
# gathering user... 891
# gathering user... 892
# gathering user... 893
# gathering user... 894
# gathering user... 895
# gathering user... 896
# gathering user... 897
# gathering user... 898
# gathering user... 899
# gathering user... 900
# gathering user... 901
# gathering user... 902
# gathering user... 903
# gathering user... 904
# gathering user... 905
# gathering user... 906
# gathering user... 907
# gathering user... 908
# gathering user... 909
# gathering user... 910
# gathering user... 911
# gathering user... 912
# gathering user... 913
# gathering user... 914
# gathering user... 915
# gathering user... 916
# gathering user... 917
# gathering user... 918
# gathering user... 919
# gathering user... 920
# gathering user... 921
# gathering user... 922
# gathering user... 923
# gathering user... 924
# gathering user... 925
# gathering user... 926
# gathering user... 927
# gathering user... 928
# gathering user... 929
# gathering user... 930
# gathering user... 931
# gathering user... 932
# gathering user... 933
# gathering user... 934
# gathering user... 935
# gathering user... 936
# gathering user... 937
# gathering user... 938
# gathering user... 939
# gathering user... 940
# gathering user... 941
# gathering user... 942
# gathering user... 943
# gathering user... 944
# gathering user... 945
# gathering user... 946
# gathering user... 947
# gathering user... 948
# gathering user... 949
# gathering user... 950
# gathering user... 951
# gathering user... 952
# gathering user... 953
# gathering user... 954
# gathering user... 955
# gathering user... 956
# gathering user... 957
# gathering user... 958
# gathering user... 959
# gathering user... 960
# gathering user... 961
# gathering user... 962
# gathering user... 963
# gathering user... 964
# gathering user... 965
# gathering user... 966
# gathering user... 967
# gathering user... 968
# gathering user... 969
# gathering user... 970
# gathering user... 971
# gathering user... 972
# gathering user... 973
# gathering user... 974
# gathering user... 975
# gathering user... 976
# gathering user... 977
# gathering user... 978
# gathering user... 979
# gathering user... 980
# gathering user... 981
# gathering user... 982
# gathering user... 983
# gathering user... 984
# gathering user... 985
# gathering user... 986
# gathering user... 987
# gathering user... 988
# gathering user... 989
# gathering user... 990
# gathering user... 991
# gathering user... 992
# gathering user... 993
# gathering user... 994
# gathering user... 995
# gathering user... 996
# gathering user... 997
# gathering user... 998
# gathering user... 999
# gathering user... 1000
# gathering user... 1001
# gathering user... 1002
# gathering user... 1003
# gathering user... 1004
# gathering user... 1005
# gathering user... 1006
# gathering user... 1007
# gathering user... 1008
# gathering user... 1009
# gathering user... 1010
# gathering user... 1011
# gathering user... 1012
# gathering user... 1013
# gathering user... 1014
# gathering user... 1015
# gathering user... 1016
# gathering user... 1017
# gathering user... 1018
# gathering user... 1019
# gathering user... 1020
# gathering user... 1021
# gathering user... 1022
# gathering user... 1023
# gathering user... 1024
# gathering user... 1025
# gathering user... 1026
# gathering user... 1027
# gathering user... 1028
# gathering user... 1029
# gathering user... 1030
# gathering user... 1031
# gathering user... 1032
# gathering user... 1033
# gathering user... 1034
# gathering user... 1035
# gathering user... 1036
# gathering user... 1037
# gathering user... 1038
# gathering user... 1039
# gathering user... 1040
# gathering user... 1041
# gathering user... 1042
# gathering user... 1043
# gathering user... 1044
# gathering user... 1045
# gathering user... 1046
# gathering user... 1047
# gathering user... 1048
# gathering user... 1049
# gathering user... 1050
# gathering user... 1051
# gathering user... 1052
# gathering user... 1053
# gathering user... 1054
# gathering user... 1055
# gathering user... 1056
# gathering user... 1057
# gathering user... 1058
# gathering user... 1059
# gathering user... 1060
# gathering user... 1061
# gathering user... 1062
# gathering user... 1063
# gathering user... 1064
# gathering user... 1065
# gathering user... 1066
# gathering user... 1067
# gathering user... 1068
# gathering user... 1069
# gathering user... 1070
# gathering user... 1071
# gathering user... 1072
# gathering user... 1073
# gathering user... 1074
# gathering user... 1075
# gathering user... 1076
# gathering user... 1077
# gathering user... 1078
# gathering user... 1079
# gathering user... 1080
# gathering user... 1081
# gathering user... 1082
# gathering user... 1083
# gathering user... 1084
# gathering user... 1085
# gathering user... 1086
# gathering user... 1087
# gathering user... 1088
# gathering user... 1089
# gathering user... 1090
# gathering user... 1091
# gathering user... 1092
# gathering user... 1093
# gathering user... 1094
# gathering user... 1095
# gathering user... 1096
# gathering user... 1097
# gathering user... 1098
# gathering user... 1099
# gathering user... 1100
# gathering user... 1101
# gathering user... 1102
# gathering user... 1103
# gathering user... 1104
# gathering user... 1105
# gathering user... 1106
# gathering user... 1107
# gathering user... 1108
# gathering user... 1109
# gathering user... 1110
# gathering user... 1111
# gathering user... 1112
# gathering user... 1113
# gathering user... 1114
# gathering user... 1115
# gathering user... 1116
# gathering user... 1117
# gathering user... 1118
# gathering user... 1119
# gathering user... 1120
# gathering user... 1121
# gathering user... 1122
# gathering user... 1123
# gathering user... 1124
# gathering user... 1125
# gathering user... 1126
# gathering user... 1127
# gathering user... 1128
# gathering user... 1129
# gathering user... 1130
# gathering user... 1131
# gathering user... 1132
# gathering user... 1133
# gathering user... 1134
# gathering user... 1135
# gathering user... 1136
# gathering user... 1137
# gathering user... 1138
# gathering user... 1139
# gathering user... 1140
# gathering user... 1141
# gathering user... 1142
# gathering user... 1143
# gathering user... 1144
# gathering user... 1145
# gathering user... 1146
# gathering user... 1147
# gathering user... 1148
# gathering user... 1149
# gathering user... 1150
# gathering user... 1151
# gathering user... 1152
# gathering user... 1153
# gathering user... 1154
# gathering user... 1155
# gathering user... 1156
# gathering user... 1157
# gathering user... 1158
# gathering user... 1159
# gathering user... 1160
# gathering user... 1161
# gathering user... 1162
# gathering user... 1163
# gathering user... 1164
# gathering user... 1165
# gathering user... 1166
# gathering user... 1167
# gathering user... 1168
# gathering user... 1169
# gathering user... 1170
# gathering user... 1171
# gathering user... 1172
# gathering user... 1173
# gathering user... 1174
# gathering user... 1175
# gathering user... 1176
# gathering user... 1177
# gathering user... 1178
# gathering user... 1179
# gathering user... 1180
# gathering user... 1181
# gathering user... 1182
# gathering user... 1183
# gathering user... 1184
# gathering user... 1185
# gathering user... 1186
# gathering user... 1187
# gathering user... 1188
# gathering user... 1189
# gathering user... 1190
# gathering user... 1191
# gathering user... 1192
# gathering user... 1193
# gathering user... 1194
# gathering user... 1195
# gathering user... 1196
# gathering user... 1197
# gathering user... 1198
# gathering user... 1199
# gathering user... 1200
# gathering user... 1201
# gathering user... 1202
# gathering user... 1203
# gathering user... 1204
# gathering user... 1205
# gathering user... 1206
# gathering user... 1207
# gathering user... 1208
# gathering user... 1209
# gathering user... 1210
# gathering user... 1211
# gathering user... 1212
# gathering user... 1213
# gathering user... 1214
# gathering user... 1215
# gathering user... 1216
# gathering user... 1217
# gathering user... 1218
# gathering user... 1219
# gathering user... 1220
# gathering user... 1221
# gathering user... 1222
# gathering user... 1223
# gathering user... 1224
# gathering user... 1225
# gathering user... 1226
# gathering user... 1227
# gathering user... 1228
# gathering user... 1229
# gathering user... 1230
# gathering user... 1231
# gathering user... 1232
# gathering user... 1233
# gathering user... 1234
# gathering user... 1235
# gathering user... 1236
# gathering user... 1237
# gathering user... 1238
# gathering user... 1239
# gathering user... 1240
# gathering user... 1241
# gathering user... 1242
# gathering user... 1243
# gathering user... 1244
# gathering user... 1245
# gathering user... 1246
# gathering user... 1247
# gathering user... 1248
# gathering user... 1249
# gathering user... 1250
# gathering user... 1251
# gathering user... 1252
# gathering user... 1253
# gathering user... 1254
# gathering user... 1255
# gathering user... 1256
# gathering user... 1257
# gathering user... 1258
# gathering user... 1259
# gathering user... 1260
# gathering user... 1261
# gathering user... 1262
# gathering user... 1263
# gathering user... 1264
# gathering user... 1265
# gathering user... 1266
# gathering user... 1267
# gathering user... 1268
# gathering user... 1269
# gathering user... 1270
# gathering user... 1271
# gathering user... 1272
# gathering user... 1273
# gathering user... 1274
# gathering user... 1275
# gathering user... 1276
# gathering user... 1277
# gathering user... 1278
# gathering user... 1279
# gathering user... 1280
# gathering user... 1281
# gathering user... 1282
# gathering user... 1283
# gathering user... 1284
# gathering user... 1285
# gathering user... 1286
# gathering user... 1287
# gathering user... 1288
# gathering user... 1289
# gathering user... 1290
# gathering user... 1291
# gathering user... 1292
# gathering user... 1293
# gathering user... 1294
# gathering user... 1295
# gathering user... 1296
# gathering user... 1297
# gathering user... 1298
# gathering user... 1299
# gathering user... 1300
# gathering user... 1301
# gathering user... 1302
# gathering user... 1303
# gathering user... 1304
# gathering user... 1305
# gathering user... 1306
# gathering user... 1307
# gathering user... 1308
# gathering user... 1309
# gathering user... 1310
# gathering user... 1311
# gathering user... 1312
# gathering user... 1313
# gathering user... 1314
# gathering user... 1315
# gathering user... 1316
# gathering user... 1317
# gathering user... 1318
# gathering user... 1319
# gathering user... 1320
# gathering user... 1321
# gathering user... 1322
# gathering user... 1323
# gathering user... 1324
# gathering user... 1325
# gathering user... 1326
# gathering user... 1327
# gathering user... 1328
# gathering user... 1329
# gathering user... 1330
# gathering user... 1331
# gathering user... 1332
# gathering user... 1333
# gathering user... 1334
# gathering user... 1335
# gathering user... 1336
# gathering user... 1337
# gathering user... 1338
# gathering user... 1339
# gathering user... 1340
# gathering user... 1341
# gathering user... 1342
# gathering user... 1343
# gathering user... 1344
# gathering user... 1345
# gathering user... 1346
# gathering user... 1347
# gathering user... 1348
# gathering user... 1349
# gathering user... 1350
# gathering user... 1351
# gathering user... 1352
# gathering user... 1353
# gathering user... 1354
# gathering user... 1355
# gathering user... 1356
# gathering user... 1357
# gathering user... 1358
# gathering user... 1359
# gathering user... 1360
# gathering user... 1361
# gathering user... 1362
# gathering user... 1363
# gathering user... 1364
# gathering user... 1365
# gathering user... 1366
# gathering user... 1367
# gathering user... 1368
# gathering user... 1369
# gathering user... 1370
# gathering user... 1371
# gathering user... 1372
# gathering user... 1373
# gathering user... 1374
# gathering user... 1375
# gathering user... 1376
# gathering user... 1377
# gathering user... 1378
# gathering user... 1379
# gathering user... 1380
# gathering user... 1381
# gathering user... 1382
# gathering user... 1383
# gathering user... 1384
# gathering user... 1385
# gathering user... 1386
# gathering user... 1387
# gathering user... 1388
# gathering user... 1389
# gathering user... 1390
# gathering user... 1391
# gathering user... 1392
# gathering user... 1393
# gathering user... 1394
# gathering user... 1395
# gathering user... 1396
# gathering user... 1397
# gathering user... 1398
# gathering user... 1399
# gathering user... 1400
# gathering user... 1401
# gathering user... 1402
# gathering user... 1403
# gathering user... 1404
# gathering user... 1405
# gathering user... 1406
# gathering user... 1407
# gathering user... 1408
# gathering user... 1409
# gathering user... 1410
# gathering user... 1411
# gathering user... 1412
# gathering user... 1413
# gathering user... 1414
# gathering user... 1415
# gathering user... 1416
# gathering user... 1417
# gathering user... 1418
# gathering user... 1419
# gathering user... 1420
# gathering user... 1421
# gathering user... 1422
# gathering user... 1423
# gathering user... 1424
# gathering user... 1425
# gathering user... 1426
# gathering user... 1427
# gathering user... 1428
# gathering user... 1429
# gathering user... 1430
# gathering user... 1431
# gathering user... 1432
# gathering user... 1433
# gathering user... 1434
# gathering user... 1435
# gathering user... 1436
# gathering user... 1437
# gathering user... 1438
# gathering user... 1439
# gathering user... 1440
# gathering user... 1441
# gathering user... 1442
# gathering user... 1443
# gathering user... 1444
# gathering user... 1445
# gathering user... 1446
# gathering user... 1447
# gathering user... 1448
# gathering user... 1449
# gathering user... 1450
# gathering user... 1451
# gathering user... 1452
# gathering user... 1453
# gathering user... 1454
# gathering user... 1455
# gathering user... 1456
# gathering user... 1457
# gathering user... 1458
# gathering user... 1459
# gathering user... 1460
# gathering user... 1461
# gathering user... 1462
# gathering user... 1463
# gathering user... 1464
# gathering user... 1465
# gathering user... 1466
# gathering user... 1467
# gathering user... 1468
# gathering user... 1469
# gathering user... 1470
# gathering user... 1471
# gathering user... 1472
# gathering user... 1473
# gathering user... 1474
# gathering user... 1475
# gathering user... 1476
# gathering user... 1477
# gathering user... 1478
# gathering user... 1479
# gathering user... 1480
# gathering user... 1481
# gathering user... 1482
# gathering user... 1483
# gathering user... 1484
# gathering user... 1485
# gathering user... 1486
# gathering user... 1487
# gathering user... 1488
# gathering user... 1489
# gathering user... 1490
# gathering user... 1491
# gathering user... 1492
# gathering user... 1493
# gathering user... 1494
# gathering user... 1495
# gathering user... 1496
# gathering user... 1497
# gathering user... 1498
# gathering user... 1499
# gathering user... 1500
# gathering user... 1501
# gathering user... 1502
# gathering user... 1503
# gathering user... 1504
# gathering user... 1505
# gathering user... 1506
# gathering user... 1507
# gathering user... 1508
# gathering user... 1509
# gathering user... 1510
# gathering user... 1511
# gathering user... 1512
# gathering user... 1513
# gathering user... 1514
# gathering user... 1515
# gathering user... 1516
# gathering user... 1517
# gathering user... 1518
# gathering user... 1519
# gathering user... 1520
# gathering user... 1521
# gathering user... 1522
# gathering user... 1523
# gathering user... 1524
# gathering user... 1525
# gathering user... 1526
# gathering user... 1527
# gathering user... 1528
# gathering user... 1529
# gathering user... 1530
# gathering user... 1531
# gathering user... 1532
# gathering user... 1533
# gathering user... 1534
# gathering user... 1535
# gathering user... 1536
# gathering user... 1537
# gathering user... 1538
# gathering user... 1539
# gathering user... 1540
# gathering user... 1541
# gathering user... 1542
# gathering user... 1543
# gathering user... 1544
# gathering user... 1545
# gathering user... 1546
# gathering user... 1547
# gathering user... 1548
# gathering user... 1549
# gathering user... 1550
# gathering user... 1551
# gathering user... 1552
# gathering user... 1553
# gathering user... 1554
# gathering user... 1555
# gathering user... 1556
# gathering user... 1557
# gathering user... 1558
# gathering user... 1559
# gathering user... 1560
# gathering user... 1561
# gathering user... 1562
# gathering user... 1563
# gathering user... 1564
# gathering user... 1565
# gathering user... 1566
# gathering user... 1567
# gathering user... 1568
# gathering user... 1569
# gathering user... 1570
# gathering user... 1571
# gathering user... 1572
# gathering user... 1573
# gathering user... 1574
# gathering user... 1575
# gathering user... 1576
# gathering user... 1577
# gathering user... 1578
# gathering user... 1579
# gathering user... 1580
# gathering user... 1581
# gathering user... 1582
# gathering user... 1583
# gathering user... 1584
# gathering user... 1585
# gathering user... 1586
# gathering user... 1587
# gathering user... 1588
# gathering user... 1589
# gathering user... 1590
# gathering user... 1591
# gathering user... 1592
# gathering user... 1593
# gathering user... 1594
# gathering user... 1595
# gathering user... 1596
# gathering user... 1597
# gathering user... 1598
# gathering user... 1599
# gathering user... 1600
# gathering user... 1601
# gathering user... 1602
# gathering user... 1603
# gathering user... 1604
# gathering user... 1605
# gathering user... 1606
# gathering user... 1607
# gathering user... 1608
# gathering user... 1609
# gathering user... 1610
# gathering user... 1611
# gathering user... 1612
# gathering user... 1613
# gathering user... 1614
# gathering user... 1615
# gathering user... 1616
# gathering user... 1617
# gathering user... 1618
# gathering user... 1619
# gathering user... 1620
# gathering user... 1621
# gathering user... 1622
# gathering user... 1623
# gathering user... 1624
# gathering user... 1625
# gathering user... 1626
# gathering user... 1627
# gathering user... 1628
# gathering user... 1629
# gathering user... 1630
# gathering user... 1631
# gathering user... 1632
# gathering user... 1633
# gathering user... 1634
# gathering user... 1635
# gathering user... 1636
# gathering user... 1637
# gathering user... 1638
# gathering user... 1639
# gathering user... 1640
# gathering user... 1641
# gathering user... 1642
# gathering user... 1643
# gathering user... 1644
# gathering user... 1645
# gathering user... 1646
# gathering user... 1647
# gathering user... 1648
# gathering user... 1649
# gathering user... 1650
# gathering user... 1651
# gathering user... 1652
# gathering user... 1653
# gathering user... 1654
# gathering user... 1655
# gathering user... 1656
# gathering user... 1657
# gathering user... 1658
# gathering user... 1659
# gathering user... 1660
# gathering user... 1661
# gathering user... 1662
# gathering user... 1663
# gathering user... 1664
# gathering user... 1665
# gathering user... 1666
# gathering user... 1667
# gathering user... 1668
# gathering user... 1669
# gathering user... 1670
# gathering user... 1671
# gathering user... 1672
# gathering user... 1673
# gathering user... 1674
# gathering user... 1675
# gathering user... 1676
# gathering user... 1677
# gathering user... 1678
# gathering user... 1679
# gathering user... 1680
# gathering user... 1681
# gathering user... 1682
# gathering user... 1683
# gathering user... 1684
# gathering user... 1685
# gathering user... 1686
# gathering user... 1687
# gathering user... 1688
# gathering user... 1689
# gathering user... 1690
# gathering user... 1691
# gathering user... 1692
# gathering user... 1693
# gathering user... 1694
# gathering user... 1695
# gathering user... 1696
# gathering user... 1697
# gathering user... 1698
# gathering user... 1699
# gathering user... 1700
# gathering user... 1701
# gathering user... 1702
# gathering user... 1703
# gathering user... 1704
# gathering user... 1705
# gathering user... 1706
# gathering user... 1707
# gathering user... 1708
# gathering user... 1709
# gathering user... 1710
# gathering user... 1711
# gathering user... 1712
# gathering user... 1713
# gathering user... 1714
# gathering user... 1715
# gathering user... 1716
# gathering user... 1717
# gathering user... 1718
# gathering user... 1719
# gathering user... 1720
# gathering user... 1721
# gathering user... 1722
# gathering user... 1723
# gathering user... 1724
# gathering user... 1725
# gathering user... 1726
# gathering user... 1727
# gathering user... 1728
# gathering user... 1729
# gathering user... 1730
# gathering user... 1731
# gathering user... 1732
# gathering user... 1733
# gathering user... 1734
# gathering user... 1735
# gathering user... 1736
# gathering user... 1737
# gathering user... 1738
# gathering user... 1739
# gathering user... 1740
# gathering user... 1741
# gathering user... 1742
# gathering user... 1743
# gathering user... 1744
# gathering user... 1745
# gathering user... 1746
# gathering user... 1747
# gathering user... 1748
# gathering user... 1749
# gathering user... 1750
# gathering user... 1751
# gathering user... 1752
# gathering user... 1753
# gathering user... 1754
# gathering user... 1755
# gathering user... 1756
# gathering user... 1757
# gathering user... 1758
# gathering user... 1759
# gathering user... 1760
# gathering user... 1761
# gathering user... 1762
# gathering user... 1763
# gathering user... 1764
# gathering user... 1765
# gathering user... 1766
# gathering user... 1767
# gathering user... 1768
# gathering user... 1769
# gathering user... 1770
# gathering user... 1771
# gathering user... 1772
# gathering user... 1773
# gathering user... 1774
# gathering user... 1775
# gathering user... 1776
# gathering user... 1777
# gathering user... 1778
# gathering user... 1779
# gathering user... 1780
# gathering user... 1781
# gathering user... 1782
# gathering user... 1783
# gathering user... 1784
# gathering user... 1785
# gathering user... 1786
# gathering user... 1787
# gathering user... 1788
# gathering user... 1789
# gathering user... 1790
# gathering user... 1791
# gathering user... 1792
# gathering user... 1793
# gathering user... 1794
# gathering user... 1795
# gathering user... 1796
# gathering user... 1797
# gathering user... 1798
# gathering user... 1799
# gathering user... 1800
# gathering user... 1801
# gathering user... 1802
# gathering user... 1803
# gathering user... 1804
# gathering user... 1805
# gathering user... 1806
# gathering user... 1807
# gathering user... 1808
# gathering user... 1809
# gathering user... 1810
# gathering user... 1811
# gathering user... 1812
# gathering user... 1813
# gathering user... 1814
# gathering user... 1815
# gathering user... 1816
# gathering user... 1817
# gathering user... 1818
# gathering user... 1819
# gathering user... 1820
# gathering user... 1821
# gathering user... 1822
# gathering user... 1823
# gathering user... 1824
# gathering user... 1825
# gathering user... 1826
# gathering user... 1827
# gathering user... 1828
# gathering user... 1829
# gathering user... 1830
# gathering user... 1831
# gathering user... 1832
# gathering user... 1833
# gathering user... 1834
# gathering user... 1835
# gathering user... 1836
# gathering user... 1837
# gathering user... 1838
# gathering user... 1839
# gathering user... 1840
# gathering user... 1841
# gathering user... 1842
# gathering user... 1843
# gathering user... 1844
# gathering user... 1845
# gathering user... 1846
# gathering user... 1847
# gathering user... 1848
# gathering user... 1849
# gathering user... 1850
# gathering user... 1851
# gathering user... 1852
# gathering user... 1853
# gathering user... 1854
# gathering user... 1855
# gathering user... 1856
# gathering user... 1857
# gathering user... 1858
# gathering user... 1859
# gathering user... 1860
# gathering user... 1861
# gathering user... 1862
# gathering user... 1863
# gathering user... 1864
# gathering user... 1865
# gathering user... 1866
# gathering user... 1867
# gathering user... 1868
# gathering user... 1869
# gathering user... 1870
# gathering user... 1871
# gathering user... 1872
# gathering user... 1873
# gathering user... 1874
# gathering user... 1875
# gathering user... 1876
# gathering user... 1877
# gathering user... 1878
# gathering user... 1879
# gathering user... 1880
# gathering user... 1881
# gathering user... 1882
# gathering user... 1883
# gathering user... 1884
# gathering user... 1885
# gathering user... 1886
# gathering user... 1887
# gathering user... 1888
# gathering user... 1889
# gathering user... 1890
# gathering user... 1891
# gathering user... 1892
# gathering user... 1893
# gathering user... 1894
# gathering user... 1895
# gathering user... 1896
# gathering user... 1897
# gathering user... 1898
# gathering user... 1899
# gathering user... 1900
# gathering user... 1901
# gathering user... 1902
# gathering user... 1903
# gathering user... 1904
# gathering user... 1905
# gathering user... 1906
# gathering user... 1907
# gathering user... 1908
# gathering user... 1909
# gathering user... 1910
# gathering user... 1911
# gathering user... 1912
# gathering user... 1913
# gathering user... 1914
# gathering user... 1915
# gathering user... 1916
# gathering user... 1917
# gathering user... 1918
# gathering user... 1919
# gathering user... 1920
# gathering user... 1921
# gathering user... 1922
# gathering user... 1923
# gathering user... 1924
# gathering user... 1925
# gathering user... 1926
# gathering user... 1927
# gathering user... 1928
# gathering user... 1929
# gathering user... 1930
# gathering user... 1931
# gathering user... 1932
# gathering user... 1933
# gathering user... 1934
# gathering user... 1935
# gathering user... 1936
# gathering user... 1937
# gathering user... 1938
# gathering user... 1939
# gathering user... 1940
# gathering user... 1941
# gathering user... 1942
# gathering user... 1943
# gathering user... 1944
# gathering user... 1945
# gathering user... 1946
# gathering user... 1947
# gathering user... 1948
# gathering user... 1949
# gathering user... 1950
# gathering user... 1951
# gathering user... 1952
# gathering user... 1953
# gathering user... 1954
# gathering user... 1955
# gathering user... 1956
# gathering user... 1957
# gathering user... 1958
# gathering user... 1959
# gathering user... 1960
# gathering user... 1961
# gathering user... 1962
# gathering user... 1963
# gathering user... 1964
# gathering user... 1965
# gathering user... 1966
# gathering user... 1967
# gathering user... 1968
# gathering user... 1969
# gathering user... 1970
# gathering user... 1971
# gathering user... 1972
# gathering user... 1973
# gathering user... 1974
# gathering user... 1975
# gathering user... 1976
# gathering user... 1977
# gathering user... 1978
# gathering user... 1979
# gathering user... 1980
# gathering user... 1981
# gathering user... 1982
# gathering user... 1983
# gathering user... 1984
# gathering user... 1985
# gathering user... 1986
# gathering user... 1987
# gathering user... 1988
# gathering user... 1989
# gathering user... 1990
# gathering user... 1991
# gathering user... 1992
# gathering user... 1993
# gathering user... 1994
# gathering user... 1995
# gathering user... 1996
# gathering user... 1997
# gathering user... 1998
# gathering user... 1999
# gathering user... 2000
# gathering user... 2001
# gathering user... 2002
# gathering user... 2003
# gathering user... 2004
# gathering user... 2005
# gathering user... 2006
# gathering user... 2007
# gathering user... 2008
# gathering user... 2009
# gathering user... 2010
# gathering user... 2011
# gathering user... 2012
# gathering user... 2013
# gathering user... 2014
# gathering user... 2015
# gathering user... 2016
# gathering user... 2017
# gathering user... 2018
# gathering user... 2019
# gathering user... 2020
# gathering user... 2021
# gathering user... 2022
# gathering user... 2023
# gathering user... 2024
# gathering user... 2025
# gathering user... 2026
# gathering user... 2027
# gathering user... 2028
# gathering user... 2029
# gathering user... 2030
# gathering user... 2031
# gathering user... 2032
# gathering user... 2033
# gathering user... 2034
# gathering user... 2035
# gathering user... 2036
# gathering user... 2037
# gathering user... 2038
# gathering user... 2039
# gathering user... 2040
# gathering user... 2041
# gathering user... 2042
# gathering user... 2043
# gathering user... 2044
# gathering user... 2045
# gathering user... 2046
# gathering user... 2047
# gathering user... 2048
# gathering user... 2049
# gathering user... 2050
# gathering user... 2051
# gathering user... 2052
# gathering user... 2053
# gathering user... 2054
# gathering user... 2055
# gathering user... 2056
# gathering user... 2057
# gathering user... 2058
# gathering user... 2059
# gathering user... 2060
# gathering user... 2061
# gathering user... 2062
# gathering user... 2063
# gathering user... 2064
# gathering user... 2065
# gathering user... 2066
# gathering user... 2067
# gathering user... 2068
# gathering user... 2069
# gathering user... 2070
# gathering user... 2071
# gathering user... 2072
# gathering user... 2073
# gathering user... 2074
# gathering user... 2075
# gathering user... 2076
# gathering user... 2077
# gathering user... 2078
# gathering user... 2079
# gathering user... 2080
# gathering user... 2081
# gathering user... 2082
# gathering user... 2083
# gathering user... 2084
# gathering user... 2085
# gathering user... 2086
# gathering user... 2087
# gathering user... 2088
# gathering user... 2089
# gathering user... 2090
# gathering user... 2091
# gathering user... 2092
# gathering user... 2093
# gathering user... 2094
# gathering user... 2095
# gathering user... 2096
# gathering user... 2097
# gathering user... 2098
# gathering user... 2099
# gathering user... 2100
# gathering user... 2101
# gathering user... 2102
# gathering user... 2103
# gathering user... 2104
# gathering user... 2105
# gathering user... 2106
# gathering user... 2107
# gathering user... 2108
# gathering user... 2109
# gathering user... 2110
# gathering user... 2111
# gathering user... 2112
# gathering user... 2113
# gathering user... 2114
# gathering user... 2115
# gathering user... 2116
# gathering user... 2117
# gathering user... 2118
# gathering user... 2119
# gathering user... 2120
# gathering user... 2121
# gathering user... 2122
# gathering user... 2123
# gathering user... 2124
# gathering user... 2125
# gathering user... 2126
# gathering user... 2127
# gathering user... 2128
# gathering user... 2129
# gathering user... 2130
# gathering user... 2131
# gathering user... 2132
# gathering user... 2133
# gathering user... 2134
# ...
# gathering user... 7057
# gathering user... 7058
# gathering user... 7059
# gathering user... 7060
# gathering user... 7061
# gathering user... 7062
# gathering user... 7063
# gathering user... 7064
# gathering user... 7065
# gathering user... 7066
# gathering user... 7067
# gathering user... 7068
# gathering user... 7069
# gathering user... 7070
# gathering user... 7071
# gathering user... 7072
# gathering user... 7073
# gathering user... 7074
# gathering user... 7075
# gathering user... 7076
# gathering user... 7077
# gathering user... 7078
# gathering user... 7079
# gathering user... 7080
# gathering user... 7081
# gathering user... 7082
# gathering user... 7083
# gathering user... 7084
# gathering user... 7085
# gathering user... 7086
# gathering user... 7087
# gathering user... 7088
# gathering user... 7089
# gathering user... 7090
# gathering user... 7091
# gathering user... 7092
# gathering user... 7093
# gathering user... 7094
# gathering user... 7095
# gathering user... 7096
# gathering user... 7097
# gathering user... 7098
# gathering user... 7099
# gathering user... 7100
# gathering user... 7101
# gathering user... 7102
# gathering user... 7103
# gathering user... 7104
# gathering user... 7105
# gathering user... 7106
# gathering user... 7107
# gathering user... 7108
# gathering user... 7109
# gathering user... 7110
# gathering user... 7111
# gathering user... 7112
# gathering user... 7113
# gathering user... 7114
# gathering user... 7115
# gathering user... 7116
# gathering user... 7117
# gathering user... 7118
# gathering user... 7119
# gathering user... 7120
# gathering user... 7121
# gathering user... 7122
# gathering user... 7123
# gathering user... 7124
# gathering user... 7125
# gathering user... 7126
# gathering user... 7127
# gathering user... 7128
# gathering user... 7129
# gathering user... 7130
# gathering user... 7131
# gathering user... 7132
# gathering user... 7133
# gathering user... 7134
# gathering user... 7135
# gathering user... 7136
# gathering user... 7137
# gathering user... 7138
# gathering user... 7139
# gathering user... 7140
# gathering user... 7141
# gathering user... 7142
# gathering user... 7143
# gathering user... 7144
# gathering user... 7145
# gathering user... 7146
# gathering user... 7147
# gathering user... 7148
# gathering user... 7149
# gathering user... 7150
# gathering user... 7151
# gathering user... 7152
# gathering user... 7153
# gathering user... 7154
# gathering user... 7155
# gathering user... 7156
# gathering user... 7157
# gathering user... 7158
# gathering user... 7159
# gathering user... 7160
# gathering user... 7161
# gathering user... 7162
# gathering user... 7163
# gathering user... 7164
# gathering user... 7165
# gathering user... 7166
# gathering user... 7167
# gathering user... 7168
# gathering user... 7169
# gathering user... 7170
# gathering user... 7171
# gathering user... 7172
# gathering user... 7173
# gathering user... 7174
# gathering user... 7175
# gathering user... 7176
# gathering user... 7177
# gathering user... 7178
# gathering user... 7179
# gathering user... 7180
# gathering user... 7181
# gathering user... 7182
# gathering user... 7183
# gathering user... 7184
# gathering user... 7185
# gathering user... 7186
# gathering user... 7187
# gathering user... 7188
# gathering user... 7189
# gathering user... 7190
# gathering user... 7191
# gathering user... 7192
# gathering user... 7193
# gathering user... 7194
# gathering user... 7195
# gathering user... 7196
# gathering user... 7197
# gathering user... 7198
# gathering user... 7199
# gathering user... 7200
# gathering user... 7201
# gathering user... 7202
# gathering user... 7203
# gathering user... 7204
# gathering user... 7205
# gathering user... 7206
# gathering user... 7207
# gathering user... 7208
# gathering user... 7209
# gathering user... 7210
# gathering user... 7211
# gathering user... 7212
# gathering user... 7213
# gathering user... 7214
# gathering user... 7215
# gathering user... 7216
# gathering user... 7217
# gathering user... 7218
# gathering user... 7219
# gathering user... 7220
# gathering user... 7221
# gathering user... 7222
# gathering user... 7223
# gathering user... 7224
# gathering user... 7225
# gathering user... 7226
# gathering user... 7227
# gathering user... 7228
# gathering user... 7229
# gathering user... 7230
# gathering user... 7231
# gathering user... 7232
# gathering user... 7233
# gathering user... 7234
# gathering user... 7235
# gathering user... 7236
# gathering user... 7237
# gathering user... 7238
# gathering user... 7239
# gathering user... 7240
# gathering user... 7241
# gathering user... 7242
# gathering user... 7243
# gathering user... 7244
# gathering user... 7245
# gathering user... 7246
# gathering user... 7247
# gathering user... 7248
# gathering user... 7249
# gathering user... 7250
# gathering user... 7251
# gathering user... 7252
# gathering user... 7253
# gathering user... 7254
# gathering user... 7255
# gathering user... 7256
# gathering user... 7257
# gathering user... 7258
# gathering user... 7259
# gathering user... 7260
# gathering user... 7261
# gathering user... 7262
# gathering user... 7263
# gathering user... 7264
# gathering user... 7265
# gathering user... 7266
# gathering user... 7267
# gathering user... 7268
# gathering user... 7269
# gathering user... 7270
# gathering user... 7271
# gathering user... 7272
# gathering user... 7273
# gathering user... 7274
# gathering user... 7275
# gathering user... 7276
# gathering user... 7277
# gathering user... 7278
# gathering user... 7279
# gathering user... 7280
# gathering user... 7281
# gathering user... 7282
# gathering user... 7283
# gathering user... 7284
# gathering user... 7285
# gathering user... 7286
# gathering user... 7287
# gathering user... 7288
# gathering user... 7289
# gathering user... 7290
# gathering user... 7291
# gathering user... 7292
# gathering user... 7293
# gathering user... 7294
# gathering user... 7295
# gathering user... 7296
# gathering user... 7297
# gathering user... 7298
# gathering user... 7299
# gathering user... 7300
# gathering user... 7301
# gathering user... 7302
# gathering user... 7303
# gathering user... 7304
# gathering user... 7305
# gathering user... 7306
# gathering user... 7307
# gathering user... 7308
# gathering user... 7309
# gathering user... 7310
# gathering user... 7311
# gathering user... 7312
# gathering user... 7313
# gathering user... 7314
# gathering user... 7315
# gathering user... 7316
# gathering user... 7317
# gathering user... 7318
# gathering user... 7319
# gathering user... 7320
# gathering user... 7321
# gathering user... 7322
# gathering user... 7323
# gathering user... 7324
# gathering user... 7325
# gathering user... 7326
# gathering user... 7327
# gathering user... 7328
# gathering user... 7329
# gathering user... 7330
# gathering user... 7331
# gathering user... 7332
# gathering user... 7333
# gathering user... 7334
# gathering user... 7335
# gathering user... 7336
# gathering user... 7337
# gathering user... 7338
# gathering user... 7339
# gathering user... 7340
# gathering user... 7341
# gathering user... 7342
# gathering user... 7343
# gathering user... 7344
# gathering user... 7345
# gathering user... 7346
# gathering user... 7347
# gathering user... 7348
# gathering user... 7349
# gathering user... 7350
# gathering user... 7351
# gathering user... 7352
# gathering user... 7353
# gathering user... 7354
# gathering user... 7355
# gathering user... 7356
# gathering user... 7357
# gathering user... 7358
# gathering user... 7359
# gathering user... 7360
# gathering user... 7361
# gathering user... 7362
# gathering user... 7363
# gathering user... 7364
# gathering user... 7365
# gathering user... 7366
# gathering user... 7367
# gathering user... 7368
# gathering user... 7369
# gathering user... 7370
# gathering user... 7371
# gathering user... 7372
# gathering user... 7373
# gathering user... 7374
# gathering user... 7375
# gathering user... 7376
# gathering user... 7377
# gathering user... 7378
# gathering user... 7379
# gathering user... 7380
# gathering user... 7381
# gathering user... 7382
# gathering user... 7383
# gathering user... 7384
# gathering user... 7385
# gathering user... 7386
# gathering user... 7387
# gathering user... 7388
# gathering user... 7389
# gathering user... 7390
# gathering user... 7391
# gathering user... 7392
# gathering user... 7393
# gathering user... 7394
# gathering user... 7395
# gathering user... 7396
# gathering user... 7397
# gathering user... 7398
# gathering user... 7399
# gathering user... 7400
# gathering user... 7401
# gathering user... 7402
# gathering user... 7403
# gathering user... 7404
# gathering user... 7405
# gathering user... 7406
# gathering user... 7407
# gathering user... 7408
# gathering user... 7409
# gathering user... 7410
# gathering user... 7411
# gathering user... 7412
# gathering user... 7413
# gathering user... 7414
# gathering user... 7415
# gathering user... 7416
# gathering user... 7417
# gathering user... 7418
# gathering user... 7419
# gathering user... 7420
# gathering user... 7421
# gathering user... 7422
# gathering user... 7423
# gathering user... 7424
# gathering user... 7425
# gathering user... 7426
# gathering user... 7427
# gathering user... 7428
# gathering user... 7429
# gathering user... 7430
# gathering user... 7431
# gathering user... 7432
# gathering user... 7433
# gathering user... 7434
# gathering user... 7435
# gathering user... 7436
# gathering user... 7437
# gathering user... 7438
# gathering user... 7439
# gathering user... 7440
# gathering user... 7441
# gathering user... 7442
# gathering user... 7443
# gathering user... 7444
# gathering user... 7445
# gathering user... 7446
# gathering user... 7447
# gathering user... 7448
# gathering user... 7449
# gathering user... 7450
# gathering user... 7451
# gathering user... 7452
# gathering user... 7453
# gathering user... 7454
# gathering user... 7455
# gathering user... 7456
# gathering user... 7457
# gathering user... 7458
# gathering user... 7459
# gathering user... 7460
# gathering user... 7461
# gathering user... 7462
# gathering user... 7463
# gathering user... 7464
# gathering user... 7465
# gathering user... 7466
# gathering user... 7467
# gathering user... 7468
# gathering user... 7469
# gathering user... 7470
# gathering user... 7471
# gathering user... 7472
# gathering user... 7473
# gathering user... 7474
# gathering user... 7475
# gathering user... 7476
# gathering user... 7477
# gathering user... 7478
# gathering user... 7479
# gathering user... 7480
# gathering user... 7481
# gathering user... 7482
# gathering user... 7483
# gathering user... 7484
# gathering user... 7485
# gathering user... 7486
# gathering user... 7487
# gathering user... 7488
# gathering user... 7489
# gathering user... 7490
# gathering user... 7491
# gathering user... 7492
# gathering user... 7493
# gathering user... 7494
# gathering user... 7495
# gathering user... 7496
# gathering user... 7497
# gathering user... 7498
# gathering user... 7499
# gathering user... 7500
# gathering user... 7501
# gathering user... 7502
# gathering user... 7503
# gathering user... 7504
# gathering user... 7505
# gathering user... 7506
# gathering user... 7507
# gathering user... 7508
# gathering user... 7509
# gathering user... 7510
# gathering user... 7511
# gathering user... 7512
# gathering user... 7513
# gathering user... 7514
# gathering user... 7515
# gathering user... 7516
# gathering user... 7517
# gathering user... 7518
# gathering user... 7519
# gathering user... 7520
# gathering user... 7521
# gathering user... 7522
# gathering user... 7523
# gathering user... 7524
# gathering user... 7525
# gathering user... 7526
# gathering user... 7527
# gathering user... 7528
# gathering user... 7529
# gathering user... 7530
# gathering user... 7531
# gathering user... 7532
# gathering user... 7533
# gathering user... 7534
# gathering user... 7535
# gathering user... 7536
# gathering user... 7537
# gathering user... 7538
# gathering user... 7539
# gathering user... 7540
# gathering user... 7541
# gathering user... 7542
# gathering user... 7543
# gathering user... 7544
# gathering user... 7545
# gathering user... 7546
# gathering user... 7547
# gathering user... 7548
# gathering user... 7549
# gathering user... 7550
# gathering user... 7551
# gathering user... 7552
# gathering user... 7553
# gathering user... 7554
# gathering user... 7555
# gathering user... 7556
# gathering user... 7557
# gathering user... 7558
# gathering user... 7559
# gathering user... 7560
# gathering user... 7561
# gathering user... 7562
# gathering user... 7563
# gathering user... 7564
# gathering user... 7565
# gathering user... 7566
# gathering user... 7567
# gathering user... 7568
# gathering user... 7569
# gathering user... 7570
# gathering user... 7571
# gathering user... 7572
# gathering user... 7573
# gathering user... 7574
# gathering user... 7575
# gathering user... 7576
# gathering user... 7577
# gathering user... 7578
# gathering user... 7579
# gathering user... 7580
# gathering user... 7581
# gathering user... 7582
# gathering user... 7583
# gathering user... 7584
# gathering user... 7585
# gathering user... 7586
# gathering user... 7587
# gathering user... 7588
# gathering user... 7589
# gathering user... 7590
# gathering user... 7591
# gathering user... 7592
# gathering user... 7593
# gathering user... 7594
# gathering user... 7595
# gathering user... 7596
# gathering user... 7597
# gathering user... 7598
# gathering user... 7599
# gathering user... 7600
# gathering user... 7601
# gathering user... 7602
# gathering user... 7603
# gathering user... 7604
# gathering user... 7605
# gathering user... 7606
# gathering user... 7607
# gathering user... 7608
# gathering user... 7609
# gathering user... 7610
# gathering user... 7611
# gathering user... 7612
# gathering user... 7613
# gathering user... 7614
# gathering user... 7615
# gathering user... 7616
# gathering user... 7617
# gathering user... 7618
# gathering user... 7619
# gathering user... 7620
# gathering user... 7621
# gathering user... 7622
# gathering user... 7623
# gathering user... 7624
# gathering user... 7625
# gathering user... 7626
# gathering user... 7627
# gathering user... 7628
# gathering user... 7629
# gathering user... 7630
# gathering user... 7631
# gathering user... 7632
# gathering user... 7633
# gathering user... 7634
# gathering user... 7635
# gathering user... 7636
# gathering user... 7637
# gathering user... 7638
# gathering user... 7639
# gathering user... 7640
# gathering user... 7641
# gathering user... 7642
# gathering user... 7643
# gathering user... 7644
# gathering user... 7645
# gathering user... 7646
# gathering user... 7647
# gathering user... 7648
# gathering user... 7649
# gathering user... 7650
# gathering user... 7651
# gathering user... 7652
# gathering user... 7653
# gathering user... 7654
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-d8763891690f> in <module>()
#       3 for tweet in tweepy.Cursor(api.search, q="IVoted",
#       4                            #since="2014-02-14", #until="2014-02-15",
# ----> 5                            lang="en").items(10000):
#       6
#       7     print("gathering user...",counter)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     162                                     if self.wait_on_rate_limit_notify:
#     163                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 164                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     165
#     166                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
ivoted_users
# Out:
# Empty DataFrame
# Columns: [bot, created_at, default_profile, default_profile_image, description, favourites_count, followers_count, friends_count, has_extended_profile, id, id_str, lang, listed_count, location, name, screen_name, status, statuses_count, url, verified]
# Index: []

# %%
ivoted_users['created_at'] = created_at
ivoted_users['default_profile'] = default_profile
ivoted_users['default_profile_image'] = default_profile_image
ivoted_users['description'] = description
ivoted_users['favourites_count']= favourites_count
ivoted_users['followers_count'] = followers_count
ivoted_users['friends_count'] = friends_count
#ivoted_users['has_extended_profile'] = tweet.author.has_extended_profile,
ivoted_users['id'] = ids
ivoted_users['id_str'] = id_str
ivoted_users['lang'] = lang
ivoted_users['listed_count'] = listed_count
ivoted_users['location'] = location
ivoted_users['name'] = name
ivoted_users['screen_name'] = screen_name
#ivoted_users['status'] = tweet.author.statuses_count
ivoted_users['statuses_count'] = statuses_count
ivoted_users['url'] = url
ivoted_users['verified'] = verified

# %%
ivoted_users
# Out:
#       bot          created_at  default_profile  default_profile_image  \
# 0     NaN 2014-09-17 13:47:20             True                  False
# 1     NaN 2009-03-30 05:31:53            False                  False
# 2     NaN 2008-08-06 15:43:26             True                  False
# 3     NaN 2009-04-20 13:07:49             True                  False
# 4     NaN 2009-01-14 16:05:52            False                  False
# 5     NaN 2011-11-16 15:42:34            False                  False
# 6     NaN 2015-03-09 17:44:02             True                   True
# 7     NaN 2008-07-07 05:36:56            False                  False
# 8     NaN 2018-01-26 00:16:52            False                  False
# 9     NaN 2015-03-20 03:02:26            False                  False
# 10    NaN 2009-04-09 16:27:05            False                  False
# 11    NaN 2017-03-14 16:47:22             True                  False
# 12    NaN 2015-09-30 03:04:27            False                  False
# 13    NaN 2012-12-04 15:10:19            False                  False
# 14    NaN 2009-03-19 14:54:10            False                  False
# 15    NaN 2016-08-23 23:52:50             True                  False
# 16    NaN 2010-10-29 23:53:25            False                  False
# 17    NaN 2016-10-12 07:39:02             True                  False
# 18    NaN 2012-06-26 06:09:10            False                  False
# 19    NaN 2011-11-16 15:42:34            False                  False
# 20    NaN 2016-12-20 18:03:32             True                  False
# 21    NaN 2011-09-28 19:27:17            False                  False
# 22    NaN 2012-10-22 02:38:17            False                  False
# 23    NaN 2013-03-11 02:46:31            False                  False
# 24    NaN 2009-05-16 19:28:09            False                  False
# 25    NaN 2009-02-28 02:54:43             True                  False
# 26    NaN 2011-09-18 19:54:12             True                  False
# 27    NaN 2012-09-14 16:03:24             True                  False
# 28    NaN 2017-08-04 16:29:36             True                  False
# 29    NaN 2012-07-30 20:37:35            False                  False
# ...   ...                 ...              ...                    ...
# 7625  NaN 2009-03-23 23:26:06            False                  False
# 7626  NaN 2011-10-25 22:06:44            False                  False
# 7627  NaN 2008-12-17 04:42:23            False                  False
# 7628  NaN 2016-09-06 21:40:51             True                  False
# 7629  NaN 2012-01-08 19:11:36            False                  False
# 7630  NaN 2015-08-21 02:00:00             True                  False
# 7631  NaN 2011-05-22 01:37:50            False                  False
# 7632  NaN 2016-12-27 13:50:16             True                  False
# 7633  NaN 2010-12-15 21:21:28            False                  False
# 7634  NaN 2014-06-13 18:59:33            False                  False
# 7635  NaN 2008-12-13 17:19:55            False                  False
# 7636  NaN 2018-06-15 07:48:17             True                  False
# 7637  NaN 2009-04-05 02:52:59            False                  False
# 7638  NaN 2014-02-01 15:11:02             True                  False
# 7639  NaN 2013-04-23 03:10:18            False                  False
# 7640  NaN 2009-11-28 19:51:02             True                  False
# 7641  NaN 2008-11-30 20:38:40            False                  False
# 7642  NaN 2009-03-03 20:07:00            False                  False
# 7643  NaN 2017-01-21 04:52:30             True                  False
# 7644  NaN 2018-09-23 07:02:22             True                  False
# 7645  NaN 2013-01-04 22:50:37            False                  False
# 7646  NaN 2010-05-18 18:07:26            False                  False
# 7647  NaN 2017-07-06 14:18:38             True                  False
# 7648  NaN 2009-03-05 12:09:51            False                  False
# 7649  NaN 2011-04-07 19:56:51            False                  False
# 7650  NaN 2015-10-25 02:25:15             True                   True
# 7651  NaN 2009-08-19 02:09:55            False                  False
# 7652  NaN 2018-04-18 00:26:14             True                  False
# 7653  NaN 2017-11-30 05:09:08             True                  False
# 7654  NaN 2018-08-31 06:18:37             True                  False
#
#                                             description  favourites_count  \
# 0     Retired Public School Psychologist/Admin. The ...             13054
# 1     Retired Military wife and mom, Big Island Girl...               289
# 2                             Question Authority #RCTID             63957
# 3                                                                     122
# 4     Vocalist of @ShipCapnCrewIL. Linguistics/Anthr...               430
# 5     .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 6                                                                       0
# 7                         Founder of Rusic Records. 🥁🎧🎨              7829
# 8     Home of the grassroots effort in Texas to elec...              1870
# 9     28 year old solopreneur. Saved $200k in 4 year...             11188
# 10    Big heart, real, loyal, give 100% in all I do,...              5471
# 11    Scottish by blood, Canadian by birth, American...            170890
# 12    Raleigh, NC. 6th Grade Math & Science Teacher ...              1580
# 13                         [enter witty summation here]              5343
# 14    Enthusiastic, creative communicator who enjoys...                81
# 15              6th Grade ELA. Optimist. Forever Young.               527
# 16    ✨ My Official Twitter Account ✨ Scout's Mom🔸  ...             80467
# 17                                                                 105307
# 18                              22. Augusta University.               115
# 19    .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 20      Lupus/SLE Survivor/Advocate for Lupus Awareness             22465
# 21    BIG CLEMSON TIGERS FAN!! #ALLIN\n#CLEMSONFAMIL...             57889
# 22    Ellis, ex-librarian w/ eye-strain in tiny rura...             55951
# 23    shipping + luxury cruising GA since 2003 #BLM ...             44710
# 24                                                                   5695
# 25    Not a politician, have not written any books, ...             97047
# 26                           America. Not a vegetarian.              1351
# 27    Activist for Mother🌎 #RESIST LibDem,7th GenTex...             81026
# 28    CHHS Physics Teacher🐾 #CHPantherPride\nUTA Alu...               755
# 29    Official account of the Personalized Academic ...              1556
# ...                                                 ...               ...
# 7625  Seasoned communications and events professiona...               132
# 7626  Host of ROCK HARD with Jay Conroy Radio Show o...             13080
# 7627  née Smith, now Wilkes. Executive Director @Ame...              4789
# 7628  101 N. Franklin St. 813-255-7473 Lobster rolls...               328
# 7629                                     🖤20// yee-haw💫              4297
# 7630  Pickles and Diet Coke addict. Southern as they...                53
# 7631  Brand Ambassador for @Embrace5B Competitive Sh...               145
# 7632                                                                 1474
# 7633  Member of #gigeconomy. Lover of #superhero #co...             12344
# 7634  Homegrown 305-Miami girl w/ Brooklyn roots,of ...              2275
# 7635  'SHADE' is out NOW : https://t.co/05VZgc8KZg (...             11075
# 7636  We VOTE #BlueNoMatterWho ! We hold #LGBTQ Righ...              3437
# 7637  retired ER/ICU RN, avid gardener, naturalist. ...             24841
# 7638  🏋🏿💪🏾✊🏽✊🏾✊🏿⚓\nTrainee at Booker T's Reality of ...               958
# 7639  I'm a Photojournalist working in Atlanta for F...             15450
# 7640  I'm an average guy that loves to write.#PulpFi...              5970
# 7641  God. 90s music. Basketball. Woodworking. Good ...               395
# 7642  Atlanta via a lifetime in the Bay Area. Now: H...              2149
# 7643  Love❤️animals and🐕dogs. 🇺🇸Trump Supporter🇺🇸Bui...             24927
# 7644                 I am here😳 https://t.co/hSVLwiPSdF               581
# 7645  “If I didn’t define myself for myself, I would...              1012
# 7646  All the lonely people, where do they all come ...             73636
# 7647  Trump MAGA Persist VOTE-GOP KAG Deplorable Dre...             21914
# 7648  Expert in 'let me Google that for you.' Produc...             18373
# 7649  Susan Garren Photographer, Illustrator, Child ...             24029
# 7650                                                                43487
# 7651  Writer, runner, functional introvert. Politica...             14726
# 7652  aka cracker barrel cowboy aka Skrrrt Kobain ak...               112
# 7653      It’s not who I am underneath . . . UCF '19 🌶🌴                 2
# 7654                                     Seize the day!             26143
#
#       followers_count  friends_count has_extended_profile  \
# 0                 656           1338                  NaN
# 1                1428           1563                  NaN
# 2                 265            214                  NaN
# 3                 133            660                  NaN
# 4                 375            156                  NaN
# 5                 719            981                  NaN
# 6                   2              8                  NaN
# 7                9389           1037                  NaN
# 8                1051            184                  NaN
# 9                3954            329                  NaN
# 10               2777           1039                  NaN
# 11               8842           8389                  NaN
# 12                611            458                  NaN
# 13                466            767                  NaN
# 14                444            977                  NaN
# 15                236            318                  NaN
# 16               5928           3061                  NaN
# 17               4350           4996                  NaN
# 18                125             37                  NaN
# 19                719            981                  NaN
# 20                272             99                  NaN
# 21                971           1928                  NaN
# 22               1078           2302                  NaN
# 23               1746           2526                  NaN
# 24                700           1338                  NaN
# 25              14390          15193                  NaN
# 26                228            201                  NaN
# 27               4503           5002                  NaN
# 28                117            135                  NaN
# 29               1764            256                  NaN
# ...               ...            ...                  ...
# 7625              240           1098                  NaN
# 7626             2219            779                  NaN
# 7627            10683            905                  NaN
# 7628              169            435                  NaN
# 7629             1167            379                  NaN
# 7630               19            184                  NaN
# 7631              203            483                  NaN
# 7632               76            283                  NaN
# 7633             3988           2879                  NaN
# 7634               94            350                  NaN
# 7635            40580           3070                  NaN
# 7636              346            583                  NaN
# 7637             6225           6774                  NaN
# 7638              299            873                  NaN
# 7639             1256           1339                  NaN
# 7640             4995           4474                  NaN
# 7641              276            672                  NaN
# 7642             4188            237                  NaN
# 7643            49973          41651                  NaN
# 7644                3            252                  NaN
# 7645              168            355                  NaN
# 7646              127            564                  NaN
# 7647             6714           6629                  NaN
# 7648             3519           4985                  NaN
# 7649             1155            854                  NaN
# 7650              334             58                  NaN
# 7651              653            299                  NaN
# 7652               15             28                  NaN
# 7653                1             19                  NaN
# 7654              126            181                  NaN
#
#                        id               id_str lang  listed_count  \
# 0              2814934842           2814934842   en             7
# 1                27591409             27591409   en            59
# 2                15751317             15751317   en            19
# 3                33505373             33505373   en             4
# 4                18980973             18980973   en            19
# 5               414059980            414059980   en            27
# 6              3082043729           3082043729   en             0
# 7                15339207             15339207   en           249
# 8      956682313668194304   956682313668194304   en             3
# 9              3098686285           3098686285   en           101
# 10               30014725             30014725   en            48
# 11     841692239562653697   841692239562653697   en             8
# 12             3820420235           3820420235   en            28
# 13              988964851            988964851   en            31
# 14               25309984             25309984   en            10
# 15     768234574128218112   768234574128218112   en             1
# 16              209810887            209810887   en           137
# 17     786108904509935616   786108904509935616   en            21
# 18              618785210            618785210   en             1
# 19              414059980            414059980   en            27
# 20     811270828205703168   811270828205703168   en             5
# 21              381690871            381690871   en            34
# 22              896598403            896598403   en             9
# 23             1258428798           1258428798   en            15
# 24               40525535             40525535   en            40
# 25               22221695             22221695   en           253
# 26              375817905            375817905   en             4
# 27              823541330            823541330   en             6
# 28     893509234142392321   893509234142392321   en             2
# 29              726805380            726805380   en            10
# ...                   ...                  ...  ...           ...
# 7625             26119829             26119829   en             4
# 7626            398322691            398322691   en             8
# 7627             18182408             18182408   en           198
# 7628   773274789033209856   773274789033209856   en             6
# 7629            458607931            458607931   en             4
# 7630           3433746580           3433746580   en             0
# 7631            302945663            302945663   en             7
# 7632   813743804603891713   813743804603891713   en             0
# 7633            227079751            227079751   en             7
# 7634           2565746178           2565746178   en             1
# 7635             18101319             18101319   en           826
# 7636  1007530215789088770  1007530215789088770   en             0
# 7637             28926547             28926547   en            60
# 7638           2322469890           2322469890   en             1
# 7639           1373674610           1373674610   en            71
# 7640             93247577             93247577   en           201
# 7641             17762229             17762229   en            14
# 7642             22670108             22670108   en           198
# 7643   822668168493576192   822668168493576192   en            16
# 7644  1043757449252163584  1043757449252163584   en             0
# 7645           1061624492           1061624492   en             1
# 7646            145329747            145329747   en             5
# 7647   882967026200965121   882967026200965121   en             0
# 7648             22911403             22911403   en           175
# 7649            278699225            278699225   en           254
# 7650           4035773955           4035773955   en             0
# 7651             66878859             66878859   en            52
# 7652   986400474143313923   986400474143313923   en             0
# 7653   936099754169204736   936099754169204736   en             0
# 7654  1035411515258679296  1035411515258679296   en             0
#
#                             location                              name  \
# 0                         California                     Debbie B. 🌊🌊🌊
# 1                         Juneau, AK                        1uscgwifey
# 2                        Portland OR                     James Belcher
# 3                           Michigan                       Paul Bazely
# 4              Logan Square, Chicago                   Roger Alexander
# 5                         California                      Tomas Vera🏞️
# 6                                                              CR King
# 7      Brooklyn, NY ✈️ Nashville, TN                DARU JONES l RUSIC
# 8                         Austin, TX                   Texans For Beto
# 9                    Minneapolis, MN                              Gwen
# 10                Miami, NY,  Boston                     mandi miranda
# 11                        Texas, USA                              Teri
# 12                       Raleigh, NC                     Hannah Powell
# 13                                                           Christine
# 14                       Chicago, IL                 Timothy A. Nelson
# 15                       Raleigh, NC                    Ms. Pozoulakis
# 16                   Los Angeles, CA                     Tai Babilonia
# 17                                                                 SME
# 18                       Augusta, GA                      Alyssa Hamer
# 19                        California                      Tomas Vera🏞️
# 20                     Davenport, FL                     Lynn Williams
# 21                 North Dakota, USA                           dh_1973
# 22    Willamette Valley, Oregon, USA            plaisanter 🌊 #voteblue
# 23        usa : gadevoted.tumblr.com              cj bleep & sylviecat
# 24           Santa Cruz, California.       Jesse Kenneth Cotu Williams
# 25                             Earth      Don't Go There #ScienceBased
# 26          the island where Lost is                        Matt Boyle
# 27                      Austin Texas                             DeLiz
# 28                                                 Stephanie Schroeder
# 29            Texas State University        PACE Center at Texas State
# ...                              ...                               ...
# 7625               San Francisco, CA                        Jenn Soult
# 7626                   New York City              ROCK HARD Jay Conroy
# 7627                       NJ 🔁 D.C.                       Alex Wilkes
# 7628                       Tampa, FL                   surfturftruckFL
# 7629                              TX                               aly
# 7630                      Dallas, TX                   Alexandra Iseli
# 7631                 Mooresville, NC                       Davin Vesey
# 7632                      Denver, CO                     Jessica Moore
# 7633                              MD                      Kyle Johnson
# 7634                 Miami Beach, FL                     Joanna Palmer
# 7635                    New York, NY                     Living Colour
# 7636                     Nevada, USA     🏳️‍🌈 #IPledgeToVoteEarly 🏳️‍🌈
# 7637                       Tennessee       Kathryn Warner 🌻#Resistance
# 7638                                               Brandon J. Williams
# 7639                     Atlanta, GA                          Jim Zorn
# 7640                   Galveston, TX                   Marlin Williams
# 7641                              TN                       𝖅𝕬𝕮 𝕮𝖀𝕻𝕻𝕷𝕰𝕾
# 7642                                                      Dan Martinez
# 7643                   United States                   🇺🇸Tammy MAGA 🇺🇸
# 7644                      Topeka, KS                      Margie Faber
# 7645                      Dallas, TX                     LaDyrian Cole
# 7646                             USA                   L Robbins ☮ 💛🖤🏀
# 7647                        Virginia      SaraBeth ❤️’s Trump’s Agenda
# 7648              St. Petersburg, FL                       Phil Ammann
# 7649                             USA  Susan Garren Art Collections 👩‍🌾
# 7650                                                     Ettari Wilden
# 7651              The Sunshine State                    Tess R. Martin
# 7652                                                   Elliott Queso 🤮
# 7653           36.178173, -82.712448                   Francis Freeman
# 7654                   United States                    Keep the Hope!
#
#           screen_name status  statuses_count                      url  \
# 0      EttaLnLavender    NaN           48062                     None
# 1          1USCGWifey    NaN           14735  https://t.co/AOj7SUsr5x
# 2           Satorical    NaN           20323                     None
# 3             Pbazely    NaN             719  https://t.co/Z09xaGx47G
# 4     _RogerAlexander    NaN            7181  https://t.co/sfgBHkpbmV
# 5             dadkind    NaN           13226  https://t.co/YAIcPeYmvg
# 6           CRKing100    NaN              29                     None
# 7           darujones    NaN           32679  https://t.co/uQiJ7AvUy9
# 8       TexansForBeto    NaN            2115  https://t.co/xzTmLds6tO
# 9     FieryMillennial    NaN            5659   http://t.co/WrGNIU36fq
# 10       mandimiranda    NaN           15033   http://t.co/ONeya53KP4
# 11        Crowntiptoe    NaN          138788                     None
# 12     ohwowmrspowell    NaN            2335  https://t.co/t8emO722ek
# 13     ChristineRaina    NaN            6563  https://t.co/ovkrwax3yo
# 14     TimothyANelson    NaN             510                     None
# 15     MissPthatsMeee    NaN             627                     None
# 16          taiskates    NaN           12825  https://t.co/5FBeNI9egB
# 17     LetzBrealistic    NaN          146662                     None
# 18     alyssa_hamer21    NaN             810                     None
# 19            dadkind    NaN           13226  https://t.co/YAIcPeYmvg
# 20    LynnWil07599335    NaN           10393                     None
# 21            dh_1973    NaN           50702                     None
# 22        plaisanters    NaN           22501                     None
# 23          GAdevoted    NaN           77571                     None
# 24         Morketiden    NaN           16043                     None
# 25           bigal953    NaN           88876  https://t.co/iFVRnUhIVB
# 26    BoyleTheBromigo    NaN            2895                     None
# 27          DelizDear    NaN           55201                     None
# 28     StephanieSchro    NaN             109                     None
# 29           txstpace    NaN            4986  https://t.co/TS7H4pw0ta
# ...               ...    ...             ...                      ...
# 7625        JennSoult    NaN             557                     None
# 7626      jayfnconroy    NaN           24956  https://t.co/peZgHv6fIT
# 7627  AlexandraCSmith    NaN            9663  https://t.co/5bzCbm64gq
# 7628  surfturftruckFL    NaN             255  https://t.co/Ug3r5b7LqM
# 7629      amberleeona    NaN           16169  https://t.co/NT6TDsC9pA
# 7630       swissiseli    NaN             637                     None
# 7631     shooterdavin    NaN            1561  https://t.co/gVwrNh4l5T
# 7632     JayMoore1201    NaN             339                     None
# 7633      kjohnson284    NaN           15601  https://t.co/NwoHB7xUse
# 7634  thejoannapalmer    NaN             803                     None
# 7635     LivingColour    NaN           31977  https://t.co/ZAQ6hV9MKs
# 7636   LGBTQUniteBlue    NaN            3235                     None
# 7637    tooldtobehere    NaN           32852                     None
# 7638     BDub_F1tness    NaN             223                     None
# 7639   PhotoZorn_FOX5    NaN           12129  https://t.co/ZVIC0egZ9N
# 7640       Marlin2002    NaN           30248  https://t.co/YaykNGjPJd
# 7641      HolyHotDang    NaN           10099  https://t.co/VO1Fv96GLL
# 7642             dmar    NaN            7915                     None
# 7643       tammy_maga    NaN           49448                     None
# 7644     MargieFaber2    NaN             147  https://t.co/hSVLwiPSdF
# 7645     ladyriancole    NaN            2427  https://t.co/54KSpQ5zWQ
# 7646     thatwasmejpm    NaN           44967                     None
# 7647    SBluvsAmerica    NaN           13132                     None
# 7648       PhilAmmann    NaN          134530  https://t.co/tFiDBCNNdj
# 7649      SusanGarren    NaN           92275  https://t.co/9oU9bmLmGl
# 7650    wilden_ettari    NaN           37011                     None
# 7651    tess_r_martin    NaN            9668  https://t.co/Lbjhw6Sdni
# 7652     ElliottQueso    NaN             134                     None
# 7653  SapiensFantasia    NaN             106  https://t.co/NBenojmFVb
# 7654           MD_386    NaN           24706                     None
#
#       verified
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# ...        ...
# 7625     False
# 7626     False
# 7627      True
# 7628     False
# 7629     False
# 7630     False
# 7631     False
# 7632     False
# 7633     False
# 7634     False
# 7635      True
# 7636     False
# 7637     False
# 7638     False
# 7639     False
# 7640     False
# 7641     False
# 7642     False
# 7643     False
# 7644     False
# 7645     False
# 7646     False
# 7647     False
# 7648     False
# 7649     False
# 7650     False
# 7651     False
# 7652     False
# 7653     False
# 7654     False
#
# [7655 rows x 20 columns]

# %%
ivoted_users['bot'] = 0

# %%
ivoted_users.dtypes
# Out:
# bot                               int64
# created_at               datetime64[ns]
# default_profile                    bool
# default_profile_image              bool
# description                      object
# favourites_count                  int64
# followers_count                   int64
# friends_count                     int64
# has_extended_profile             object
# id                                int64
# id_str                           object
# lang                             object
# listed_count                      int64
# location                         object
# name                             object
# screen_name                      object
# status                           object
# statuses_count                    int64
# url                              object
# verified                           bool
# dtype: object

# %%
ivoted_users
# Out:
#       bot          created_at  default_profile  default_profile_image  \
# 0       0 2014-09-17 13:47:20             True                  False
# 1       0 2009-03-30 05:31:53            False                  False
# 2       0 2008-08-06 15:43:26             True                  False
# 3       0 2009-04-20 13:07:49             True                  False
# 4       0 2009-01-14 16:05:52            False                  False
# 5       0 2011-11-16 15:42:34            False                  False
# 6       0 2015-03-09 17:44:02             True                   True
# 7       0 2008-07-07 05:36:56            False                  False
# 8       0 2018-01-26 00:16:52            False                  False
# 9       0 2015-03-20 03:02:26            False                  False
# 10      0 2009-04-09 16:27:05            False                  False
# 11      0 2017-03-14 16:47:22             True                  False
# 12      0 2015-09-30 03:04:27            False                  False
# 13      0 2012-12-04 15:10:19            False                  False
# 14      0 2009-03-19 14:54:10            False                  False
# 15      0 2016-08-23 23:52:50             True                  False
# 16      0 2010-10-29 23:53:25            False                  False
# 17      0 2016-10-12 07:39:02             True                  False
# 18      0 2012-06-26 06:09:10            False                  False
# 19      0 2011-11-16 15:42:34            False                  False
# 20      0 2016-12-20 18:03:32             True                  False
# 21      0 2011-09-28 19:27:17            False                  False
# 22      0 2012-10-22 02:38:17            False                  False
# 23      0 2013-03-11 02:46:31            False                  False
# 24      0 2009-05-16 19:28:09            False                  False
# 25      0 2009-02-28 02:54:43             True                  False
# 26      0 2011-09-18 19:54:12             True                  False
# 27      0 2012-09-14 16:03:24             True                  False
# 28      0 2017-08-04 16:29:36             True                  False
# 29      0 2012-07-30 20:37:35            False                  False
# ...   ...                 ...              ...                    ...
# 7625    0 2009-03-23 23:26:06            False                  False
# 7626    0 2011-10-25 22:06:44            False                  False
# 7627    0 2008-12-17 04:42:23            False                  False
# 7628    0 2016-09-06 21:40:51             True                  False
# 7629    0 2012-01-08 19:11:36            False                  False
# 7630    0 2015-08-21 02:00:00             True                  False
# 7631    0 2011-05-22 01:37:50            False                  False
# 7632    0 2016-12-27 13:50:16             True                  False
# 7633    0 2010-12-15 21:21:28            False                  False
# 7634    0 2014-06-13 18:59:33            False                  False
# 7635    0 2008-12-13 17:19:55            False                  False
# 7636    0 2018-06-15 07:48:17             True                  False
# 7637    0 2009-04-05 02:52:59            False                  False
# 7638    0 2014-02-01 15:11:02             True                  False
# 7639    0 2013-04-23 03:10:18            False                  False
# 7640    0 2009-11-28 19:51:02             True                  False
# 7641    0 2008-11-30 20:38:40            False                  False
# 7642    0 2009-03-03 20:07:00            False                  False
# 7643    0 2017-01-21 04:52:30             True                  False
# 7644    0 2018-09-23 07:02:22             True                  False
# 7645    0 2013-01-04 22:50:37            False                  False
# 7646    0 2010-05-18 18:07:26            False                  False
# 7647    0 2017-07-06 14:18:38             True                  False
# 7648    0 2009-03-05 12:09:51            False                  False
# 7649    0 2011-04-07 19:56:51            False                  False
# 7650    0 2015-10-25 02:25:15             True                   True
# 7651    0 2009-08-19 02:09:55            False                  False
# 7652    0 2018-04-18 00:26:14             True                  False
# 7653    0 2017-11-30 05:09:08             True                  False
# 7654    0 2018-08-31 06:18:37             True                  False
#
#                                             description  favourites_count  \
# 0     Retired Public School Psychologist/Admin. The ...             13054
# 1     Retired Military wife and mom, Big Island Girl...               289
# 2                             Question Authority #RCTID             63957
# 3                                                                     122
# 4     Vocalist of @ShipCapnCrewIL. Linguistics/Anthr...               430
# 5     .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 6                                                                       0
# 7                         Founder of Rusic Records. 🥁🎧🎨              7829
# 8     Home of the grassroots effort in Texas to elec...              1870
# 9     28 year old solopreneur. Saved $200k in 4 year...             11188
# 10    Big heart, real, loyal, give 100% in all I do,...              5471
# 11    Scottish by blood, Canadian by birth, American...            170890
# 12    Raleigh, NC. 6th Grade Math & Science Teacher ...              1580
# 13                         [enter witty summation here]              5343
# 14    Enthusiastic, creative communicator who enjoys...                81
# 15              6th Grade ELA. Optimist. Forever Young.               527
# 16    ✨ My Official Twitter Account ✨ Scout's Mom🔸  ...             80467
# 17                                                                 105307
# 18                              22. Augusta University.               115
# 19    .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 20      Lupus/SLE Survivor/Advocate for Lupus Awareness             22465
# 21    BIG CLEMSON TIGERS FAN!! #ALLIN\n#CLEMSONFAMIL...             57889
# 22    Ellis, ex-librarian w/ eye-strain in tiny rura...             55951
# 23    shipping + luxury cruising GA since 2003 #BLM ...             44710
# 24                                                                   5695
# 25    Not a politician, have not written any books, ...             97047
# 26                           America. Not a vegetarian.              1351
# 27    Activist for Mother🌎 #RESIST LibDem,7th GenTex...             81026
# 28    CHHS Physics Teacher🐾 #CHPantherPride\nUTA Alu...               755
# 29    Official account of the Personalized Academic ...              1556
# ...                                                 ...               ...
# 7625  Seasoned communications and events professiona...               132
# 7626  Host of ROCK HARD with Jay Conroy Radio Show o...             13080
# 7627  née Smith, now Wilkes. Executive Director @Ame...              4789
# 7628  101 N. Franklin St. 813-255-7473 Lobster rolls...               328
# 7629                                     🖤20// yee-haw💫              4297
# 7630  Pickles and Diet Coke addict. Southern as they...                53
# 7631  Brand Ambassador for @Embrace5B Competitive Sh...               145
# 7632                                                                 1474
# 7633  Member of #gigeconomy. Lover of #superhero #co...             12344
# 7634  Homegrown 305-Miami girl w/ Brooklyn roots,of ...              2275
# 7635  'SHADE' is out NOW : https://t.co/05VZgc8KZg (...             11075
# 7636  We VOTE #BlueNoMatterWho ! We hold #LGBTQ Righ...              3437
# 7637  retired ER/ICU RN, avid gardener, naturalist. ...             24841
# 7638  🏋🏿💪🏾✊🏽✊🏾✊🏿⚓\nTrainee at Booker T's Reality of ...               958
# 7639  I'm a Photojournalist working in Atlanta for F...             15450
# 7640  I'm an average guy that loves to write.#PulpFi...              5970
# 7641  God. 90s music. Basketball. Woodworking. Good ...               395
# 7642  Atlanta via a lifetime in the Bay Area. Now: H...              2149
# 7643  Love❤️animals and🐕dogs. 🇺🇸Trump Supporter🇺🇸Bui...             24927
# 7644                 I am here😳 https://t.co/hSVLwiPSdF               581
# 7645  “If I didn’t define myself for myself, I would...              1012
# 7646  All the lonely people, where do they all come ...             73636
# 7647  Trump MAGA Persist VOTE-GOP KAG Deplorable Dre...             21914
# 7648  Expert in 'let me Google that for you.' Produc...             18373
# 7649  Susan Garren Photographer, Illustrator, Child ...             24029
# 7650                                                                43487
# 7651  Writer, runner, functional introvert. Politica...             14726
# 7652  aka cracker barrel cowboy aka Skrrrt Kobain ak...               112
# 7653      It’s not who I am underneath . . . UCF '19 🌶🌴                 2
# 7654                                     Seize the day!             26143
#
#       followers_count  friends_count has_extended_profile  \
# 0                 656           1338                  NaN
# 1                1428           1563                  NaN
# 2                 265            214                  NaN
# 3                 133            660                  NaN
# 4                 375            156                  NaN
# 5                 719            981                  NaN
# 6                   2              8                  NaN
# 7                9389           1037                  NaN
# 8                1051            184                  NaN
# 9                3954            329                  NaN
# 10               2777           1039                  NaN
# 11               8842           8389                  NaN
# 12                611            458                  NaN
# 13                466            767                  NaN
# 14                444            977                  NaN
# 15                236            318                  NaN
# 16               5928           3061                  NaN
# 17               4350           4996                  NaN
# 18                125             37                  NaN
# 19                719            981                  NaN
# 20                272             99                  NaN
# 21                971           1928                  NaN
# 22               1078           2302                  NaN
# 23               1746           2526                  NaN
# 24                700           1338                  NaN
# 25              14390          15193                  NaN
# 26                228            201                  NaN
# 27               4503           5002                  NaN
# 28                117            135                  NaN
# 29               1764            256                  NaN
# ...               ...            ...                  ...
# 7625              240           1098                  NaN
# 7626             2219            779                  NaN
# 7627            10683            905                  NaN
# 7628              169            435                  NaN
# 7629             1167            379                  NaN
# 7630               19            184                  NaN
# 7631              203            483                  NaN
# 7632               76            283                  NaN
# 7633             3988           2879                  NaN
# 7634               94            350                  NaN
# 7635            40580           3070                  NaN
# 7636              346            583                  NaN
# 7637             6225           6774                  NaN
# 7638              299            873                  NaN
# 7639             1256           1339                  NaN
# 7640             4995           4474                  NaN
# 7641              276            672                  NaN
# 7642             4188            237                  NaN
# 7643            49973          41651                  NaN
# 7644                3            252                  NaN
# 7645              168            355                  NaN
# 7646              127            564                  NaN
# 7647             6714           6629                  NaN
# 7648             3519           4985                  NaN
# 7649             1155            854                  NaN
# 7650              334             58                  NaN
# 7651              653            299                  NaN
# 7652               15             28                  NaN
# 7653                1             19                  NaN
# 7654              126            181                  NaN
#
#                        id               id_str lang  listed_count  \
# 0              2814934842           2814934842   en             7
# 1                27591409             27591409   en            59
# 2                15751317             15751317   en            19
# 3                33505373             33505373   en             4
# 4                18980973             18980973   en            19
# 5               414059980            414059980   en            27
# 6              3082043729           3082043729   en             0
# 7                15339207             15339207   en           249
# 8      956682313668194304   956682313668194304   en             3
# 9              3098686285           3098686285   en           101
# 10               30014725             30014725   en            48
# 11     841692239562653697   841692239562653697   en             8
# 12             3820420235           3820420235   en            28
# 13              988964851            988964851   en            31
# 14               25309984             25309984   en            10
# 15     768234574128218112   768234574128218112   en             1
# 16              209810887            209810887   en           137
# 17     786108904509935616   786108904509935616   en            21
# 18              618785210            618785210   en             1
# 19              414059980            414059980   en            27
# 20     811270828205703168   811270828205703168   en             5
# 21              381690871            381690871   en            34
# 22              896598403            896598403   en             9
# 23             1258428798           1258428798   en            15
# 24               40525535             40525535   en            40
# 25               22221695             22221695   en           253
# 26              375817905            375817905   en             4
# 27              823541330            823541330   en             6
# 28     893509234142392321   893509234142392321   en             2
# 29              726805380            726805380   en            10
# ...                   ...                  ...  ...           ...
# 7625             26119829             26119829   en             4
# 7626            398322691            398322691   en             8
# 7627             18182408             18182408   en           198
# 7628   773274789033209856   773274789033209856   en             6
# 7629            458607931            458607931   en             4
# 7630           3433746580           3433746580   en             0
# 7631            302945663            302945663   en             7
# 7632   813743804603891713   813743804603891713   en             0
# 7633            227079751            227079751   en             7
# 7634           2565746178           2565746178   en             1
# 7635             18101319             18101319   en           826
# 7636  1007530215789088770  1007530215789088770   en             0
# 7637             28926547             28926547   en            60
# 7638           2322469890           2322469890   en             1
# 7639           1373674610           1373674610   en            71
# 7640             93247577             93247577   en           201
# 7641             17762229             17762229   en            14
# 7642             22670108             22670108   en           198
# 7643   822668168493576192   822668168493576192   en            16
# 7644  1043757449252163584  1043757449252163584   en             0
# 7645           1061624492           1061624492   en             1
# 7646            145329747            145329747   en             5
# 7647   882967026200965121   882967026200965121   en             0
# 7648             22911403             22911403   en           175
# 7649            278699225            278699225   en           254
# 7650           4035773955           4035773955   en             0
# 7651             66878859             66878859   en            52
# 7652   986400474143313923   986400474143313923   en             0
# 7653   936099754169204736   936099754169204736   en             0
# 7654  1035411515258679296  1035411515258679296   en             0
#
#                             location                              name  \
# 0                         California                     Debbie B. 🌊🌊🌊
# 1                         Juneau, AK                        1uscgwifey
# 2                        Portland OR                     James Belcher
# 3                           Michigan                       Paul Bazely
# 4              Logan Square, Chicago                   Roger Alexander
# 5                         California                      Tomas Vera🏞️
# 6                                                              CR King
# 7      Brooklyn, NY ✈️ Nashville, TN                DARU JONES l RUSIC
# 8                         Austin, TX                   Texans For Beto
# 9                    Minneapolis, MN                              Gwen
# 10                Miami, NY,  Boston                     mandi miranda
# 11                        Texas, USA                              Teri
# 12                       Raleigh, NC                     Hannah Powell
# 13                                                           Christine
# 14                       Chicago, IL                 Timothy A. Nelson
# 15                       Raleigh, NC                    Ms. Pozoulakis
# 16                   Los Angeles, CA                     Tai Babilonia
# 17                                                                 SME
# 18                       Augusta, GA                      Alyssa Hamer
# 19                        California                      Tomas Vera🏞️
# 20                     Davenport, FL                     Lynn Williams
# 21                 North Dakota, USA                           dh_1973
# 22    Willamette Valley, Oregon, USA            plaisanter 🌊 #voteblue
# 23        usa : gadevoted.tumblr.com              cj bleep & sylviecat
# 24           Santa Cruz, California.       Jesse Kenneth Cotu Williams
# 25                             Earth      Don't Go There #ScienceBased
# 26          the island where Lost is                        Matt Boyle
# 27                      Austin Texas                             DeLiz
# 28                                                 Stephanie Schroeder
# 29            Texas State University        PACE Center at Texas State
# ...                              ...                               ...
# 7625               San Francisco, CA                        Jenn Soult
# 7626                   New York City              ROCK HARD Jay Conroy
# 7627                       NJ 🔁 D.C.                       Alex Wilkes
# 7628                       Tampa, FL                   surfturftruckFL
# 7629                              TX                               aly
# 7630                      Dallas, TX                   Alexandra Iseli
# 7631                 Mooresville, NC                       Davin Vesey
# 7632                      Denver, CO                     Jessica Moore
# 7633                              MD                      Kyle Johnson
# 7634                 Miami Beach, FL                     Joanna Palmer
# 7635                    New York, NY                     Living Colour
# 7636                     Nevada, USA     🏳️‍🌈 #IPledgeToVoteEarly 🏳️‍🌈
# 7637                       Tennessee       Kathryn Warner 🌻#Resistance
# 7638                                               Brandon J. Williams
# 7639                     Atlanta, GA                          Jim Zorn
# 7640                   Galveston, TX                   Marlin Williams
# 7641                              TN                       𝖅𝕬𝕮 𝕮𝖀𝕻𝕻𝕷𝕰𝕾
# 7642                                                      Dan Martinez
# 7643                   United States                   🇺🇸Tammy MAGA 🇺🇸
# 7644                      Topeka, KS                      Margie Faber
# 7645                      Dallas, TX                     LaDyrian Cole
# 7646                             USA                   L Robbins ☮ 💛🖤🏀
# 7647                        Virginia      SaraBeth ❤️’s Trump’s Agenda
# 7648              St. Petersburg, FL                       Phil Ammann
# 7649                             USA  Susan Garren Art Collections 👩‍🌾
# 7650                                                     Ettari Wilden
# 7651              The Sunshine State                    Tess R. Martin
# 7652                                                   Elliott Queso 🤮
# 7653           36.178173, -82.712448                   Francis Freeman
# 7654                   United States                    Keep the Hope!
#
#           screen_name status  statuses_count                      url  \
# 0      EttaLnLavender    NaN           48062                     None
# 1          1USCGWifey    NaN           14735  https://t.co/AOj7SUsr5x
# 2           Satorical    NaN           20323                     None
# 3             Pbazely    NaN             719  https://t.co/Z09xaGx47G
# 4     _RogerAlexander    NaN            7181  https://t.co/sfgBHkpbmV
# 5             dadkind    NaN           13226  https://t.co/YAIcPeYmvg
# 6           CRKing100    NaN              29                     None
# 7           darujones    NaN           32679  https://t.co/uQiJ7AvUy9
# 8       TexansForBeto    NaN            2115  https://t.co/xzTmLds6tO
# 9     FieryMillennial    NaN            5659   http://t.co/WrGNIU36fq
# 10       mandimiranda    NaN           15033   http://t.co/ONeya53KP4
# 11        Crowntiptoe    NaN          138788                     None
# 12     ohwowmrspowell    NaN            2335  https://t.co/t8emO722ek
# 13     ChristineRaina    NaN            6563  https://t.co/ovkrwax3yo
# 14     TimothyANelson    NaN             510                     None
# 15     MissPthatsMeee    NaN             627                     None
# 16          taiskates    NaN           12825  https://t.co/5FBeNI9egB
# 17     LetzBrealistic    NaN          146662                     None
# 18     alyssa_hamer21    NaN             810                     None
# 19            dadkind    NaN           13226  https://t.co/YAIcPeYmvg
# 20    LynnWil07599335    NaN           10393                     None
# 21            dh_1973    NaN           50702                     None
# 22        plaisanters    NaN           22501                     None
# 23          GAdevoted    NaN           77571                     None
# 24         Morketiden    NaN           16043                     None
# 25           bigal953    NaN           88876  https://t.co/iFVRnUhIVB
# 26    BoyleTheBromigo    NaN            2895                     None
# 27          DelizDear    NaN           55201                     None
# 28     StephanieSchro    NaN             109                     None
# 29           txstpace    NaN            4986  https://t.co/TS7H4pw0ta
# ...               ...    ...             ...                      ...
# 7625        JennSoult    NaN             557                     None
# 7626      jayfnconroy    NaN           24956  https://t.co/peZgHv6fIT
# 7627  AlexandraCSmith    NaN            9663  https://t.co/5bzCbm64gq
# 7628  surfturftruckFL    NaN             255  https://t.co/Ug3r5b7LqM
# 7629      amberleeona    NaN           16169  https://t.co/NT6TDsC9pA
# 7630       swissiseli    NaN             637                     None
# 7631     shooterdavin    NaN            1561  https://t.co/gVwrNh4l5T
# 7632     JayMoore1201    NaN             339                     None
# 7633      kjohnson284    NaN           15601  https://t.co/NwoHB7xUse
# 7634  thejoannapalmer    NaN             803                     None
# 7635     LivingColour    NaN           31977  https://t.co/ZAQ6hV9MKs
# 7636   LGBTQUniteBlue    NaN            3235                     None
# 7637    tooldtobehere    NaN           32852                     None
# 7638     BDub_F1tness    NaN             223                     None
# 7639   PhotoZorn_FOX5    NaN           12129  https://t.co/ZVIC0egZ9N
# 7640       Marlin2002    NaN           30248  https://t.co/YaykNGjPJd
# 7641      HolyHotDang    NaN           10099  https://t.co/VO1Fv96GLL
# 7642             dmar    NaN            7915                     None
# 7643       tammy_maga    NaN           49448                     None
# 7644     MargieFaber2    NaN             147  https://t.co/hSVLwiPSdF
# 7645     ladyriancole    NaN            2427  https://t.co/54KSpQ5zWQ
# 7646     thatwasmejpm    NaN           44967                     None
# 7647    SBluvsAmerica    NaN           13132                     None
# 7648       PhilAmmann    NaN          134530  https://t.co/tFiDBCNNdj
# 7649      SusanGarren    NaN           92275  https://t.co/9oU9bmLmGl
# 7650    wilden_ettari    NaN           37011                     None
# 7651    tess_r_martin    NaN            9668  https://t.co/Lbjhw6Sdni
# 7652     ElliottQueso    NaN             134                     None
# 7653  SapiensFantasia    NaN             106  https://t.co/NBenojmFVb
# 7654           MD_386    NaN           24706                     None
#
#       verified
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# ...        ...
# 7625     False
# 7626     False
# 7627      True
# 7628     False
# 7629     False
# 7630     False
# 7631     False
# 7632     False
# 7633     False
# 7634     False
# 7635      True
# 7636     False
# 7637     False
# 7638     False
# 7639     False
# 7640     False
# 7641     False
# 7642     False
# 7643     False
# 7644     False
# 7645     False
# 7646     False
# 7647     False
# 7648     False
# 7649     False
# 7650     False
# 7651     False
# 7652     False
# 7653     False
# 7654     False
#
# [7655 rows x 20 columns]

# %%
for col in ivoted_users.columns:
    if ivoted_users[col].dtypes == 'float64':
       # russ_bots[col].astype(int)
        #print('yes', col, russ_bots[col].dtypes)
        ivoted_users[col] = ivoted_users[col].astype(int)

# %%
ivoted_users.dtypes
ivoted_users.columns
# Out:
# Index(['bot', 'created_at', 'default_profile', 'default_profile_image',
#        'description', 'favourites_count', 'followers_count', 'friends_count',
#        'has_extended_profile', 'id', 'id_str', 'lang', 'listed_count',
#        'location', 'name', 'screen_name', 'status', 'statuses_count', 'url',
#        'verified'],
#       dtype='object')

# %%
ivoted_users.isna().sum()
ivoted_users.isnull().sum()
# Out:
# bot                      0
# created_at               0
# default_profile          0
# default_profile_image    0
# description              0
# favourites_count         0
# followers_count          0
# friends_count            0
# has_extended_profile     0
# id                       0
# id_str                   0
# lang                     0
# listed_count             0
# location                 0
# name                     0
# screen_name              0
# status                   0
# statuses_count           0
# url                      0
# verified                 0
# dtype: int64

# %%
ivoted_users['description'] = ivoted_users.description.fillna('No description')
ivoted_users['location'] = ivoted_users.location.fillna('No location')
ivoted_users['url'] = ivoted_users.url.fillna('No URL')
ivoted_users['status'] = ivoted_users.status.fillna('No status')
ivoted_users['has_extended_profile'] = ivoted_users.has_extended_profile.fillna('No extd. profile')

# %%
ivoted_users.dtypes
# Out:
# bot                               int64
# created_at               datetime64[ns]
# default_profile                    bool
# default_profile_image              bool
# description                      object
# favourites_count                  int64
# followers_count                   int64
# friends_count                     int64
# has_extended_profile             object
# id                                int64
# id_str                           object
# lang                             object
# listed_count                      int64
# location                         object
# name                             object
# screen_name                      object
# status                           object
# statuses_count                    int64
# url                              object
# verified                           bool
# dtype: object

# %%
ivoted_users
# Out:
#       bot          created_at  default_profile  default_profile_image  \
# 0       0 2014-09-17 13:47:20             True                  False
# 1       0 2009-03-30 05:31:53            False                  False
# 2       0 2008-08-06 15:43:26             True                  False
# 3       0 2009-04-20 13:07:49             True                  False
# 4       0 2009-01-14 16:05:52            False                  False
# 5       0 2011-11-16 15:42:34            False                  False
# 6       0 2015-03-09 17:44:02             True                   True
# 7       0 2008-07-07 05:36:56            False                  False
# 8       0 2018-01-26 00:16:52            False                  False
# 9       0 2015-03-20 03:02:26            False                  False
# 10      0 2009-04-09 16:27:05            False                  False
# 11      0 2017-03-14 16:47:22             True                  False
# 12      0 2015-09-30 03:04:27            False                  False
# 13      0 2012-12-04 15:10:19            False                  False
# 14      0 2009-03-19 14:54:10            False                  False
# 15      0 2016-08-23 23:52:50             True                  False
# 16      0 2010-10-29 23:53:25            False                  False
# 17      0 2016-10-12 07:39:02             True                  False
# 18      0 2012-06-26 06:09:10            False                  False
# 19      0 2011-11-16 15:42:34            False                  False
# 20      0 2016-12-20 18:03:32             True                  False
# 21      0 2011-09-28 19:27:17            False                  False
# 22      0 2012-10-22 02:38:17            False                  False
# 23      0 2013-03-11 02:46:31            False                  False
# 24      0 2009-05-16 19:28:09            False                  False
# 25      0 2009-02-28 02:54:43             True                  False
# 26      0 2011-09-18 19:54:12             True                  False
# 27      0 2012-09-14 16:03:24             True                  False
# 28      0 2017-08-04 16:29:36             True                  False
# 29      0 2012-07-30 20:37:35            False                  False
# ...   ...                 ...              ...                    ...
# 7625    0 2009-03-23 23:26:06            False                  False
# 7626    0 2011-10-25 22:06:44            False                  False
# 7627    0 2008-12-17 04:42:23            False                  False
# 7628    0 2016-09-06 21:40:51             True                  False
# 7629    0 2012-01-08 19:11:36            False                  False
# 7630    0 2015-08-21 02:00:00             True                  False
# 7631    0 2011-05-22 01:37:50            False                  False
# 7632    0 2016-12-27 13:50:16             True                  False
# 7633    0 2010-12-15 21:21:28            False                  False
# 7634    0 2014-06-13 18:59:33            False                  False
# 7635    0 2008-12-13 17:19:55            False                  False
# 7636    0 2018-06-15 07:48:17             True                  False
# 7637    0 2009-04-05 02:52:59            False                  False
# 7638    0 2014-02-01 15:11:02             True                  False
# 7639    0 2013-04-23 03:10:18            False                  False
# 7640    0 2009-11-28 19:51:02             True                  False
# 7641    0 2008-11-30 20:38:40            False                  False
# 7642    0 2009-03-03 20:07:00            False                  False
# 7643    0 2017-01-21 04:52:30             True                  False
# 7644    0 2018-09-23 07:02:22             True                  False
# 7645    0 2013-01-04 22:50:37            False                  False
# 7646    0 2010-05-18 18:07:26            False                  False
# 7647    0 2017-07-06 14:18:38             True                  False
# 7648    0 2009-03-05 12:09:51            False                  False
# 7649    0 2011-04-07 19:56:51            False                  False
# 7650    0 2015-10-25 02:25:15             True                   True
# 7651    0 2009-08-19 02:09:55            False                  False
# 7652    0 2018-04-18 00:26:14             True                  False
# 7653    0 2017-11-30 05:09:08             True                  False
# 7654    0 2018-08-31 06:18:37             True                  False
#
#                                             description  favourites_count  \
# 0     Retired Public School Psychologist/Admin. The ...             13054
# 1     Retired Military wife and mom, Big Island Girl...               289
# 2                             Question Authority #RCTID             63957
# 3                                                                     122
# 4     Vocalist of @ShipCapnCrewIL. Linguistics/Anthr...               430
# 5     .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 6                                                                       0
# 7                         Founder of Rusic Records. 🥁🎧🎨              7829
# 8     Home of the grassroots effort in Texas to elec...              1870
# 9     28 year old solopreneur. Saved $200k in 4 year...             11188
# 10    Big heart, real, loyal, give 100% in all I do,...              5471
# 11    Scottish by blood, Canadian by birth, American...            170890
# 12    Raleigh, NC. 6th Grade Math & Science Teacher ...              1580
# 13                         [enter witty summation here]              5343
# 14    Enthusiastic, creative communicator who enjoys...                81
# 15              6th Grade ELA. Optimist. Forever Young.               527
# 16    ✨ My Official Twitter Account ✨ Scout's Mom🔸  ...             80467
# 17                                                                 105307
# 18                              22. Augusta University.               115
# 19    .NET developer * US Navy Vet  * Democrat * Lat...             10860
# 20      Lupus/SLE Survivor/Advocate for Lupus Awareness             22465
# 21    BIG CLEMSON TIGERS FAN!! #ALLIN\n#CLEMSONFAMIL...             57889
# 22    Ellis, ex-librarian w/ eye-strain in tiny rura...             55951
# 23    shipping + luxury cruising GA since 2003 #BLM ...             44710
# 24                                                                   5695
# 25    Not a politician, have not written any books, ...             97047
# 26                           America. Not a vegetarian.              1351
# 27    Activist for Mother🌎 #RESIST LibDem,7th GenTex...             81026
# 28    CHHS Physics Teacher🐾 #CHPantherPride\nUTA Alu...               755
# 29    Official account of the Personalized Academic ...              1556
# ...                                                 ...               ...
# 7625  Seasoned communications and events professiona...               132
# 7626  Host of ROCK HARD with Jay Conroy Radio Show o...             13080
# 7627  née Smith, now Wilkes. Executive Director @Ame...              4789
# 7628  101 N. Franklin St. 813-255-7473 Lobster rolls...               328
# 7629                                     🖤20// yee-haw💫              4297
# 7630  Pickles and Diet Coke addict. Southern as they...                53
# 7631  Brand Ambassador for @Embrace5B Competitive Sh...               145
# 7632                                                                 1474
# 7633  Member of #gigeconomy. Lover of #superhero #co...             12344
# 7634  Homegrown 305-Miami girl w/ Brooklyn roots,of ...              2275
# 7635  'SHADE' is out NOW : https://t.co/05VZgc8KZg (...             11075
# 7636  We VOTE #BlueNoMatterWho ! We hold #LGBTQ Righ...              3437
# 7637  retired ER/ICU RN, avid gardener, naturalist. ...             24841
# 7638  🏋🏿💪🏾✊🏽✊🏾✊🏿⚓\nTrainee at Booker T's Reality of ...               958
# 7639  I'm a Photojournalist working in Atlanta for F...             15450
# 7640  I'm an average guy that loves to write.#PulpFi...              5970
# 7641  God. 90s music. Basketball. Woodworking. Good ...               395
# 7642  Atlanta via a lifetime in the Bay Area. Now: H...              2149
# 7643  Love❤️animals and🐕dogs. 🇺🇸Trump Supporter🇺🇸Bui...             24927
# 7644                 I am here😳 https://t.co/hSVLwiPSdF               581
# 7645  “If I didn’t define myself for myself, I would...              1012
# 7646  All the lonely people, where do they all come ...             73636
# 7647  Trump MAGA Persist VOTE-GOP KAG Deplorable Dre...             21914
# 7648  Expert in 'let me Google that for you.' Produc...             18373
# 7649  Susan Garren Photographer, Illustrator, Child ...             24029
# 7650                                                                43487
# 7651  Writer, runner, functional introvert. Politica...             14726
# 7652  aka cracker barrel cowboy aka Skrrrt Kobain ak...               112
# 7653      It’s not who I am underneath . . . UCF '19 🌶🌴                 2
# 7654                                     Seize the day!             26143
#
#       followers_count  friends_count has_extended_profile  \
# 0                 656           1338     No extd. profile
# 1                1428           1563     No extd. profile
# 2                 265            214     No extd. profile
# 3                 133            660     No extd. profile
# 4                 375            156     No extd. profile
# 5                 719            981     No extd. profile
# 6                   2              8     No extd. profile
# 7                9389           1037     No extd. profile
# 8                1051            184     No extd. profile
# 9                3954            329     No extd. profile
# 10               2777           1039     No extd. profile
# 11               8842           8389     No extd. profile
# 12                611            458     No extd. profile
# 13                466            767     No extd. profile
# 14                444            977     No extd. profile
# 15                236            318     No extd. profile
# 16               5928           3061     No extd. profile
# 17               4350           4996     No extd. profile
# 18                125             37     No extd. profile
# 19                719            981     No extd. profile
# 20                272             99     No extd. profile
# 21                971           1928     No extd. profile
# 22               1078           2302     No extd. profile
# 23               1746           2526     No extd. profile
# 24                700           1338     No extd. profile
# 25              14390          15193     No extd. profile
# 26                228            201     No extd. profile
# 27               4503           5002     No extd. profile
# 28                117            135     No extd. profile
# 29               1764            256     No extd. profile
# ...               ...            ...                  ...
# 7625              240           1098     No extd. profile
# 7626             2219            779     No extd. profile
# 7627            10683            905     No extd. profile
# 7628              169            435     No extd. profile
# 7629             1167            379     No extd. profile
# 7630               19            184     No extd. profile
# 7631              203            483     No extd. profile
# 7632               76            283     No extd. profile
# 7633             3988           2879     No extd. profile
# 7634               94            350     No extd. profile
# 7635            40580           3070     No extd. profile
# 7636              346            583     No extd. profile
# 7637             6225           6774     No extd. profile
# 7638              299            873     No extd. profile
# 7639             1256           1339     No extd. profile
# 7640             4995           4474     No extd. profile
# 7641              276            672     No extd. profile
# 7642             4188            237     No extd. profile
# 7643            49973          41651     No extd. profile
# 7644                3            252     No extd. profile
# 7645              168            355     No extd. profile
# 7646              127            564     No extd. profile
# 7647             6714           6629     No extd. profile
# 7648             3519           4985     No extd. profile
# 7649             1155            854     No extd. profile
# 7650              334             58     No extd. profile
# 7651              653            299     No extd. profile
# 7652               15             28     No extd. profile
# 7653                1             19     No extd. profile
# 7654              126            181     No extd. profile
#
#                        id               id_str lang  listed_count  \
# 0              2814934842           2814934842   en             7
# 1                27591409             27591409   en            59
# 2                15751317             15751317   en            19
# 3                33505373             33505373   en             4
# 4                18980973             18980973   en            19
# 5               414059980            414059980   en            27
# 6              3082043729           3082043729   en             0
# 7                15339207             15339207   en           249
# 8      956682313668194304   956682313668194304   en             3
# 9              3098686285           3098686285   en           101
# 10               30014725             30014725   en            48
# 11     841692239562653697   841692239562653697   en             8
# 12             3820420235           3820420235   en            28
# 13              988964851            988964851   en            31
# 14               25309984             25309984   en            10
# 15     768234574128218112   768234574128218112   en             1
# 16              209810887            209810887   en           137
# 17     786108904509935616   786108904509935616   en            21
# 18              618785210            618785210   en             1
# 19              414059980            414059980   en            27
# 20     811270828205703168   811270828205703168   en             5
# 21              381690871            381690871   en            34
# 22              896598403            896598403   en             9
# 23             1258428798           1258428798   en            15
# 24               40525535             40525535   en            40
# 25               22221695             22221695   en           253
# 26              375817905            375817905   en             4
# 27              823541330            823541330   en             6
# 28     893509234142392321   893509234142392321   en             2
# 29              726805380            726805380   en            10
# ...                   ...                  ...  ...           ...
# 7625             26119829             26119829   en             4
# 7626            398322691            398322691   en             8
# 7627             18182408             18182408   en           198
# 7628   773274789033209856   773274789033209856   en             6
# 7629            458607931            458607931   en             4
# 7630           3433746580           3433746580   en             0
# 7631            302945663            302945663   en             7
# 7632   813743804603891713   813743804603891713   en             0
# 7633            227079751            227079751   en             7
# 7634           2565746178           2565746178   en             1
# 7635             18101319             18101319   en           826
# 7636  1007530215789088770  1007530215789088770   en             0
# 7637             28926547             28926547   en            60
# 7638           2322469890           2322469890   en             1
# 7639           1373674610           1373674610   en            71
# 7640             93247577             93247577   en           201
# 7641             17762229             17762229   en            14
# 7642             22670108             22670108   en           198
# 7643   822668168493576192   822668168493576192   en            16
# 7644  1043757449252163584  1043757449252163584   en             0
# 7645           1061624492           1061624492   en             1
# 7646            145329747            145329747   en             5
# 7647   882967026200965121   882967026200965121   en             0
# 7648             22911403             22911403   en           175
# 7649            278699225            278699225   en           254
# 7650           4035773955           4035773955   en             0
# 7651             66878859             66878859   en            52
# 7652   986400474143313923   986400474143313923   en             0
# 7653   936099754169204736   936099754169204736   en             0
# 7654  1035411515258679296  1035411515258679296   en             0
#
#                             location                              name  \
# 0                         California                     Debbie B. 🌊🌊🌊
# 1                         Juneau, AK                        1uscgwifey
# 2                        Portland OR                     James Belcher
# 3                           Michigan                       Paul Bazely
# 4              Logan Square, Chicago                   Roger Alexander
# 5                         California                      Tomas Vera🏞️
# 6                                                              CR King
# 7      Brooklyn, NY ✈️ Nashville, TN                DARU JONES l RUSIC
# 8                         Austin, TX                   Texans For Beto
# 9                    Minneapolis, MN                              Gwen
# 10                Miami, NY,  Boston                     mandi miranda
# 11                        Texas, USA                              Teri
# 12                       Raleigh, NC                     Hannah Powell
# 13                                                           Christine
# 14                       Chicago, IL                 Timothy A. Nelson
# 15                       Raleigh, NC                    Ms. Pozoulakis
# 16                   Los Angeles, CA                     Tai Babilonia
# 17                                                                 SME
# 18                       Augusta, GA                      Alyssa Hamer
# 19                        California                      Tomas Vera🏞️
# 20                     Davenport, FL                     Lynn Williams
# 21                 North Dakota, USA                           dh_1973
# 22    Willamette Valley, Oregon, USA            plaisanter 🌊 #voteblue
# 23        usa : gadevoted.tumblr.com              cj bleep & sylviecat
# 24           Santa Cruz, California.       Jesse Kenneth Cotu Williams
# 25                             Earth      Don't Go There #ScienceBased
# 26          the island where Lost is                        Matt Boyle
# 27                      Austin Texas                             DeLiz
# 28                                                 Stephanie Schroeder
# 29            Texas State University        PACE Center at Texas State
# ...                              ...                               ...
# 7625               San Francisco, CA                        Jenn Soult
# 7626                   New York City              ROCK HARD Jay Conroy
# 7627                       NJ 🔁 D.C.                       Alex Wilkes
# 7628                       Tampa, FL                   surfturftruckFL
# 7629                              TX                               aly
# 7630                      Dallas, TX                   Alexandra Iseli
# 7631                 Mooresville, NC                       Davin Vesey
# 7632                      Denver, CO                     Jessica Moore
# 7633                              MD                      Kyle Johnson
# 7634                 Miami Beach, FL                     Joanna Palmer
# 7635                    New York, NY                     Living Colour
# 7636                     Nevada, USA     🏳️‍🌈 #IPledgeToVoteEarly 🏳️‍🌈
# 7637                       Tennessee       Kathryn Warner 🌻#Resistance
# 7638                                               Brandon J. Williams
# 7639                     Atlanta, GA                          Jim Zorn
# 7640                   Galveston, TX                   Marlin Williams
# 7641                              TN                       𝖅𝕬𝕮 𝕮𝖀𝕻𝕻𝕷𝕰𝕾
# 7642                                                      Dan Martinez
# 7643                   United States                   🇺🇸Tammy MAGA 🇺🇸
# 7644                      Topeka, KS                      Margie Faber
# 7645                      Dallas, TX                     LaDyrian Cole
# 7646                             USA                   L Robbins ☮ 💛🖤🏀
# 7647                        Virginia      SaraBeth ❤️’s Trump’s Agenda
# 7648              St. Petersburg, FL                       Phil Ammann
# 7649                             USA  Susan Garren Art Collections 👩‍🌾
# 7650                                                     Ettari Wilden
# 7651              The Sunshine State                    Tess R. Martin
# 7652                                                   Elliott Queso 🤮
# 7653           36.178173, -82.712448                   Francis Freeman
# 7654                   United States                    Keep the Hope!
#
#           screen_name     status  statuses_count                      url  \
# 0      EttaLnLavender  No status           48062                   No URL
# 1          1USCGWifey  No status           14735  https://t.co/AOj7SUsr5x
# 2           Satorical  No status           20323                   No URL
# 3             Pbazely  No status             719  https://t.co/Z09xaGx47G
# 4     _RogerAlexander  No status            7181  https://t.co/sfgBHkpbmV
# 5             dadkind  No status           13226  https://t.co/YAIcPeYmvg
# 6           CRKing100  No status              29                   No URL
# 7           darujones  No status           32679  https://t.co/uQiJ7AvUy9
# 8       TexansForBeto  No status            2115  https://t.co/xzTmLds6tO
# 9     FieryMillennial  No status            5659   http://t.co/WrGNIU36fq
# 10       mandimiranda  No status           15033   http://t.co/ONeya53KP4
# 11        Crowntiptoe  No status          138788                   No URL
# 12     ohwowmrspowell  No status            2335  https://t.co/t8emO722ek
# 13     ChristineRaina  No status            6563  https://t.co/ovkrwax3yo
# 14     TimothyANelson  No status             510                   No URL
# 15     MissPthatsMeee  No status             627                   No URL
# 16          taiskates  No status           12825  https://t.co/5FBeNI9egB
# 17     LetzBrealistic  No status          146662                   No URL
# 18     alyssa_hamer21  No status             810                   No URL
# 19            dadkind  No status           13226  https://t.co/YAIcPeYmvg
# 20    LynnWil07599335  No status           10393                   No URL
# 21            dh_1973  No status           50702                   No URL
# 22        plaisanters  No status           22501                   No URL
# 23          GAdevoted  No status           77571                   No URL
# 24         Morketiden  No status           16043                   No URL
# 25           bigal953  No status           88876  https://t.co/iFVRnUhIVB
# 26    BoyleTheBromigo  No status            2895                   No URL
# 27          DelizDear  No status           55201                   No URL
# 28     StephanieSchro  No status             109                   No URL
# 29           txstpace  No status            4986  https://t.co/TS7H4pw0ta
# ...               ...        ...             ...                      ...
# 7625        JennSoult  No status             557                   No URL
# 7626      jayfnconroy  No status           24956  https://t.co/peZgHv6fIT
# 7627  AlexandraCSmith  No status            9663  https://t.co/5bzCbm64gq
# 7628  surfturftruckFL  No status             255  https://t.co/Ug3r5b7LqM
# 7629      amberleeona  No status           16169  https://t.co/NT6TDsC9pA
# 7630       swissiseli  No status             637                   No URL
# 7631     shooterdavin  No status            1561  https://t.co/gVwrNh4l5T
# 7632     JayMoore1201  No status             339                   No URL
# 7633      kjohnson284  No status           15601  https://t.co/NwoHB7xUse
# 7634  thejoannapalmer  No status             803                   No URL
# 7635     LivingColour  No status           31977  https://t.co/ZAQ6hV9MKs
# 7636   LGBTQUniteBlue  No status            3235                   No URL
# 7637    tooldtobehere  No status           32852                   No URL
# 7638     BDub_F1tness  No status             223                   No URL
# 7639   PhotoZorn_FOX5  No status           12129  https://t.co/ZVIC0egZ9N
# 7640       Marlin2002  No status           30248  https://t.co/YaykNGjPJd
# 7641      HolyHotDang  No status           10099  https://t.co/VO1Fv96GLL
# 7642             dmar  No status            7915                   No URL
# 7643       tammy_maga  No status           49448                   No URL
# 7644     MargieFaber2  No status             147  https://t.co/hSVLwiPSdF
# 7645     ladyriancole  No status            2427  https://t.co/54KSpQ5zWQ
# 7646     thatwasmejpm  No status           44967                   No URL
# 7647    SBluvsAmerica  No status           13132                   No URL
# 7648       PhilAmmann  No status          134530  https://t.co/tFiDBCNNdj
# 7649      SusanGarren  No status           92275  https://t.co/9oU9bmLmGl
# 7650    wilden_ettari  No status           37011                   No URL
# 7651    tess_r_martin  No status            9668  https://t.co/Lbjhw6Sdni
# 7652     ElliottQueso  No status             134                   No URL
# 7653  SapiensFantasia  No status             106  https://t.co/NBenojmFVb
# 7654           MD_386  No status           24706                   No URL
#
#       verified
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# ...        ...
# 7625     False
# 7626     False
# 7627      True
# 7628     False
# 7629     False
# 7630     False
# 7631     False
# 7632     False
# 7633     False
# 7634     False
# 7635      True
# 7636     False
# 7637     False
# 7638     False
# 7639     False
# 7640     False
# 7641     False
# 7642     False
# 7643     False
# 7644     False
# 7645     False
# 7646     False
# 7647     False
# 7648     False
# 7649     False
# 7650     False
# 7651     False
# 7652     False
# 7653     False
# 7654     False
#
# [7655 rows x 20 columns]

# %%
twt_fake = pd.read_csv('/Users/pbiswas/Desktop/cresci-2015.csv/TWT.csv/users.csv')

# %%
twt_fake.head()
# Out:
#           id                  name   screen_name  statuses_count  \
# 0   80479674               YI YUAN     yi_twitts              29
# 1   82487179        Marcos Perez C   marcos_peca            1408
# 2  105830531         curti lorenzo  curtilorenzo              39
# 3  114488344  ruben dario toscano     gatito2710              59
# 4  123222267          Malek Khalaf   MalekKhalaf             987
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0               19            255                 1             0
# 1              208            866               138             0
# 2               59            962                 8             0
# 3                7             49                 4             0
# 4               60            521                61             1
#
#                        created_at                                     url  \
# 0  Wed Oct 07 03:19:21 +0000 2009                  http://www.jycondo.com
# 1  Wed Oct 14 23:40:17 +0000 2009                                     NaN
# 2  Sun Jan 17 16:46:52 +0000 2010             http://www.valcavargna.com/
# 3  Mon Feb 15 15:49:58 +0000 2010                                     NaN
# 4  Mon Mar 15 11:38:55 +0000 2010  http://www.facebook.com/Malek.AlBalawi
#
#     ...   profile_sidebar_fill_color  \
# 0   ...                       efefef
# 1   ...                       A0C5C7
# 2   ...                       C0DFEC
# 3   ...                       DDEEF6
# 4   ...                       A9A09B
#
#                         profile_background_image_url profile_background_color  \
# 0   http://a0.twimg.com/images/themes/theme14/bg.gif                   131516
# 1    http://a0.twimg.com/images/themes/theme6/bg.gif                   709397
# 2  http://a0.twimg.com/profile_background_images/...                   022330
# 3    http://a0.twimg.com/images/themes/theme1/bg.png                   C0DEED
# 4  http://a0.twimg.com/profile_background_images/...                   D9FBFC
#
#    profile_link_color  utc_offset  protected verified  \
# 0              009999    -18000.0        NaN      NaN
# 1              FF3300    -21600.0        NaN      NaN
# 2              0084B4         0.0        NaN      NaN
# 3              0084B4    -18000.0        NaN      NaN
# 4              C0C3CC     10800.0        NaN      NaN
#
#                                          description              updated  \
# 0                                 real estate sales   2015-02-14 09:55:39
# 1                                                NaN  2015-02-14 09:55:39
# 2  le corna del capro scappato dal gregge s'infil...  2015-02-14 09:55:39
# 3                                                NaN  2015-02-14 09:55:39
# 4  MA student at JU, Interested in Juventus,Italy...  2015-02-14 09:55:39
#
#   dataset
# 0     TWT
# 1     TWT
# 2     TWT
# 3     TWT
# 4     TWT
#
# [5 rows x 34 columns]

# %%
ivoted_users.to_csv('users_ivoted.csv', encoding='utf-8', index=False)

# %%
#for col in use.columns:
#    if russ_bots[col].dtypes == 'float64':
#       # russ_bots[col].astype(int)
#        #print('yes', col, russ_bots[col].dtypes)
#        russ_bots[col] = russ_bots[col].astype(int)

# %%
# new fake dataset- https://arxiv.org/pdf/1509.04098.pdf

# %%
twt_fake = pd.read_csv('/Users/pbiswas/Desktop/cresci-2015.csv/TWT.csv/users.csv')

twt_fake.head()
# Out:
#           id                  name   screen_name  statuses_count  \
# 0   80479674               YI YUAN     yi_twitts              29
# 1   82487179        Marcos Perez C   marcos_peca            1408
# 2  105830531         curti lorenzo  curtilorenzo              39
# 3  114488344  ruben dario toscano     gatito2710              59
# 4  123222267          Malek Khalaf   MalekKhalaf             987
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0               19            255                 1             0
# 1              208            866               138             0
# 2               59            962                 8             0
# 3                7             49                 4             0
# 4               60            521                61             1
#
#                        created_at                                     url  \
# 0  Wed Oct 07 03:19:21 +0000 2009                  http://www.jycondo.com
# 1  Wed Oct 14 23:40:17 +0000 2009                                     NaN
# 2  Sun Jan 17 16:46:52 +0000 2010             http://www.valcavargna.com/
# 3  Mon Feb 15 15:49:58 +0000 2010                                     NaN
# 4  Mon Mar 15 11:38:55 +0000 2010  http://www.facebook.com/Malek.AlBalawi
#
#     ...   profile_sidebar_fill_color  \
# 0   ...                       efefef
# 1   ...                       A0C5C7
# 2   ...                       C0DFEC
# 3   ...                       DDEEF6
# 4   ...                       A9A09B
#
#                         profile_background_image_url profile_background_color  \
# 0   http://a0.twimg.com/images/themes/theme14/bg.gif                   131516
# 1    http://a0.twimg.com/images/themes/theme6/bg.gif                   709397
# 2  http://a0.twimg.com/profile_background_images/...                   022330
# 3    http://a0.twimg.com/images/themes/theme1/bg.png                   C0DEED
# 4  http://a0.twimg.com/profile_background_images/...                   D9FBFC
#
#    profile_link_color  utc_offset  protected verified  \
# 0              009999    -18000.0        NaN      NaN
# 1              FF3300    -21600.0        NaN      NaN
# 2              0084B4         0.0        NaN      NaN
# 3              0084B4    -18000.0        NaN      NaN
# 4              C0C3CC     10800.0        NaN      NaN
#
#                                          description              updated  \
# 0                                 real estate sales   2015-02-14 09:55:39
# 1                                                NaN  2015-02-14 09:55:39
# 2  le corna del capro scappato dal gregge s'infil...  2015-02-14 09:55:39
# 3                                                NaN  2015-02-14 09:55:39
# 4  MA student at JU, Interested in Juventus,Italy...  2015-02-14 09:55:39
#
#   dataset
# 0     TWT
# 1     TWT
# 2     TWT
# 3     TWT
# 4     TWT
#
# [5 rows x 34 columns]

# %%
twt_fake.columns
# Out:
# Index(['id', 'name', 'screen_name', 'statuses_count', 'followers_count',
#        'friends_count', 'favourites_count', 'listed_count', 'created_at',
#        'url', 'lang', 'time_zone', 'location', 'default_profile',
#        'default_profile_image', 'geo_enabled', 'profile_image_url',
#        'profile_banner_url', 'profile_use_background_image',
#        'profile_background_image_url_https', 'profile_text_color',
#        'profile_image_url_https', 'profile_sidebar_border_color',
#        'profile_background_tile', 'profile_sidebar_fill_color',
#        'profile_background_image_url', 'profile_background_color',
#        'profile_link_color', 'utc_offset', 'protected', 'verified',
#        'description', 'updated', 'dataset'],
#       dtype='object')

# %%
['bot', 'created_at', 'default_profile', 'default_profile_image',
       'description', 'favourites_count', 'followers_count', 'friends_count',
       'has_extended_profile', 'id', 'id_str', 'lang', 'listed_count',
       'location', 'name', 'screen_name', 'status', 'statuses_count', 'url',
       'verified']

# %%
#def createOutput(data):
header = ['bot', 'created_at', 'default_profile', 'default_profile_image',
       'description', 'favourites_count', 'followers_count', 'friends_count',
       'has_extended_profile', 'id', 'id_str', 'lang', 'listed_count',
       'location', 'name', 'screen_name', 'status', 'statuses_count', 'url',
       'verified']
fake_users = pd.DataFrame(columns=header)
for key in header:
    if key not in twt_fake.columns:
        fake_users[key] = ""
    else:
        fake_users[key] = twt_fake[key]

#df = pd.DataFrame(d, columns= header, index=np.arange(1))
# df['bot'] = isbot
#return df

# %%
fake_users
# Out:
#      bot                      created_at  default_profile  \
# 0    NaN  Wed Oct 07 03:19:21 +0000 2009              NaN
# 1    NaN  Wed Oct 14 23:40:17 +0000 2009              NaN
# 2    NaN  Sun Jan 17 16:46:52 +0000 2010              NaN
# 3    NaN  Mon Feb 15 15:49:58 +0000 2010              1.0
# 4    NaN  Mon Mar 15 11:38:55 +0000 2010              NaN
# 5    NaN  Sun May 16 19:51:50 +0000 2010              1.0
# 6    NaN  Sun Nov 07 15:13:37 +0000 2010              1.0
# 7    NaN  Wed Apr 06 15:35:32 +0000 2011              1.0
# 8    NaN  Sun Sep 04 09:54:29 +0000 2011              1.0
# 9    NaN  Tue Jun 05 01:12:01 +0000 2012              1.0
# 10   NaN  Fri Dec 07 13:57:04 +0000 2007              NaN
# 11   NaN  Wed Sep 03 20:42:11 +0000 2008              1.0
# 12   NaN  Wed Oct 15 03:31:07 +0000 2008              1.0
# 13   NaN  Wed Nov 26 02:48:55 +0000 2008              NaN
# 14   NaN  Wed Nov 26 18:59:35 +0000 2008              NaN
# 15   NaN  Tue Jan 20 10:53:18 +0000 2009              1.0
# 16   NaN  Tue Feb 03 03:26:53 +0000 2009              1.0
# 17   NaN  Thu Feb 12 22:24:36 +0000 2009              1.0
# 18   NaN  Thu Feb 12 23:32:13 +0000 2009              NaN
# 19   NaN  Wed Feb 18 13:40:55 +0000 2009              NaN
# 20   NaN  Fri Feb 20 02:26:24 +0000 2009              1.0
# 21   NaN  Fri Feb 20 04:51:31 +0000 2009              NaN
# 22   NaN  Mon Feb 23 23:25:12 +0000 2009              1.0
# 23   NaN  Thu Feb 26 04:53:01 +0000 2009              1.0
# 24   NaN  Sun Mar 22 16:10:49 +0000 2009              NaN
# 25   NaN  Thu Mar 26 15:50:25 +0000 2009              NaN
# 26   NaN  Mon Mar 30 15:44:58 +0000 2009              1.0
# 27   NaN  Wed Apr 01 23:12:44 +0000 2009              1.0
# 28   NaN  Thu Apr 02 02:49:56 +0000 2009              1.0
# 29   NaN  Sat Apr 04 18:31:17 +0000 2009              1.0
# ..   ...                             ...              ...
# 815  NaN  Mon Jun 18 00:18:20 +0000 2012              1.0
# 816  NaN  Mon Jun 18 16:40:39 +0000 2012              1.0
# 817  NaN  Wed Jul 04 19:58:19 +0000 2012              NaN
# 818  NaN  Mon Jul 09 02:04:04 +0000 2012              1.0
# 819  NaN  Sun Jul 15 03:30:21 +0000 2012              1.0
# 820  NaN  Thu Jul 26 08:27:07 +0000 2012              1.0
# 821  NaN  Fri Aug 03 17:29:46 +0000 2012              1.0
# 822  NaN  Wed Aug 15 11:50:27 +0000 2012              1.0
# 823  NaN  Sat Aug 18 01:00:51 +0000 2012              1.0
# 824  NaN  Fri Aug 31 14:38:02 +0000 2012              1.0
# 825  NaN  Fri Sep 21 14:15:08 +0000 2012              1.0
# 826  NaN  Tue Sep 25 15:53:07 +0000 2012              1.0
# 827  NaN  Tue Oct 02 21:07:06 +0000 2012              NaN
# 828  NaN  Tue Oct 09 03:32:03 +0000 2012              NaN
# 829  NaN  Sun Oct 28 07:50:42 +0000 2012              1.0
# 830  NaN  Fri Nov 02 22:28:25 +0000 2012              1.0
# 831  NaN  Fri Nov 09 04:39:02 +0000 2012              1.0
# 832  NaN  Fri Nov 16 14:30:48 +0000 2012              1.0
# 833  NaN  Fri Nov 23 13:26:52 +0000 2012              1.0
# 834  NaN  Tue Nov 27 04:30:45 +0000 2012              1.0
# 835  NaN  Wed Dec 05 00:20:59 +0000 2012              1.0
# 836  NaN  Sat Dec 15 13:29:13 +0000 2012              1.0
# 837  NaN  Mon Dec 17 16:54:51 +0000 2012              1.0
# 838  NaN  Thu Dec 20 04:58:54 +0000 2012              1.0
# 839  NaN  Sun Dec 23 14:29:52 +0000 2012              1.0
# 840  NaN  Thu Jan 17 14:22:31 +0000 2013              1.0
# 841  NaN  Sat Jan 26 19:27:26 +0000 2013              1.0
# 842  NaN  Mon Jan 28 22:38:57 +0000 2013              NaN
# 843  NaN  Tue Feb 05 18:39:07 +0000 2013              1.0
# 844  NaN  Tue Mar 19 19:19:32 +0000 2013              1.0
#
#      default_profile_image                                        description  \
# 0                      NaN                                 real estate sales
# 1                      NaN                                                NaN
# 2                      NaN  le corna del capro scappato dal gregge s'infil...
# 3                      NaN                                                NaN
# 4                      NaN  MA student at JU, Interested in Juventus,Italy...
# 5                      NaN   Con Dios no necesito nada mas el es mi fortaleza
# 6                      NaN                                                NaN
# 7                      NaN                                                NaN
# 8                      NaN                                                NaN
# 9                      NaN                                                NaN
# 10                     NaN                                                NaN
# 11                     NaN                                                NaN
# 12                     NaN                                                NaN
# 13                     NaN                                                NaN
# 14                     NaN  Principal/Investor - Hillenbrand Capital Partn...
# 15                     NaN  Live life to the full never regret the past bu...
# 16                     NaN                                                NaN
# 17                     NaN                                                NaN
# 18                     NaN                                                NaN
# 19                     NaN                                                NaN
# 20                     NaN                                                NaN
# 21                     NaN               236 years...Well, we had a good run.
# 22                     NaN                                                NaN
# 23                     NaN                                                NaN
# 24                     NaN  Spirited Artist, Passionate Life Empowerment C...
# 25                     NaN  Artist,Songwriter,Producer buryourself@gmail.c...
# 26                     NaN                                                NaN
# 27                     NaN                                                NaN
# 28                     NaN                                                NaN
# 29                     NaN                                                NaN
# ..                     ...                                                ...
# 815                    NaN                                                NaN
# 816                    NaN  soy orgullosamente catolica me encanta leer la...
# 817                    NaN                                                NaN
# 818                    NaN                                                NaN
# 819                    NaN                                                NaN
# 820                    NaN                                                NaN
# 821                    NaN                                                NaN
# 822                    NaN                                                NaN
# 823                    NaN        me gusta aser trucos en bicicletasy estudio
# 824                    NaN                                                NaN
# 825                    NaN                                                NaN
# 826                    NaN                                                NaN
# 827                    NaN  lo mio lo mio es ehar desmadre y vivir la vida...
# 828                    NaN  10/3/12 -                                     ...
# 829                    NaN  http://www.youtube.com/watch?v=ESxYnlCb2Hg&fea...
# 830                    NaN                                         I'm happy.
# 831                    NaN                                                NaN
# 832                    NaN            Smoke weed every day. Get high as fuck.
# 833                    NaN                                                NaN
# 834                    NaN                                                NaN
# 835                    NaN                                      españa/madrid
# 836                    NaN                                                NaN
# 837                    NaN                                                NaN
# 838                    NaN  Looking to become a wrestler in the WWE. I thi...
# 839                    NaN                                                NaN
# 840                    NaN                                                NaN
# 841                    NaN                                  세상에서 제일 달콤한것은? :)
# 842                    NaN                                                NaN
# 843                    NaN  Je suis plusieurs dans ma tête, c'est handicap...
# 844                    NaN  I stan for lil Kim i love her music and i a ve...
#
#      favourites_count  followers_count  friends_count has_extended_profile  \
# 0                   1               19            255
# 1                 138              208            866
# 2                   8               59            962
# 3                   4                7             49
# 4                  61               60            521
# 5                   3              141           1075
# 6                   0               16            342
# 7                   0               14            287
# 8                   0                0            122
# 9                   0                4            228
# 10                  7              171           1398
# 11                 10                9            564
# 12                  0               91            527
# 13                  0               17            361
# 14                 92              583            836
# 15                  1               13            466
# 16                 13               63            901
# 17                  0                6            599
# 18                  0               18           1009
# 19                  0              130            484
# 20                  0                9            595
# 21                  7              271           1199
# 22                  0                5            549
# 23                  0               19           1031
# 24                  6              547           1286
# 25                  2              492           2004
# 26                  3               28            577
# 27                  0                3            475
# 28                  0               10            559
# 29                  0               45            568
# ..                ...              ...            ...                  ...
# 815                 1                6            550
# 816                 2               16            505
# 817                 0               11            535
# 818                 0                4            570
# 819                 0                4            366
# 820                 0                6            613
# 821                 0               27            556
# 822                 3               11            440
# 823                 1                8            627
# 824                 3               10            577
# 825                 9               38            518
# 826                 0                1            421
# 827                11               72           1295
# 828                25             1624            524
# 829                 0                5            325
# 830                 0                1            444
# 831                 0                8            393
# 832                 9               46            514
# 833                 0                0            194
# 834                 0                2            344
# 835                 0                7            446
# 836                 0                4            337
# 837                 0                3            426
# 838                 0                2            493
# 839                 0                6            130
# 840                 0                2            325
# 841                 4                2            307
# 842                 0                2            314
# 843                 0                6            482
# 844               106              137            414
#
#              id id_str lang  listed_count                        location  \
# 0      80479674          en             0                         toronto
# 1      82487179          es             0                             NaN
# 2     105830531          it             0  San Bartolomeo Val Cavargna CO
# 3     114488344          es             0                            peru
# 4     123222267          en             1             31.975193,35.920294
# 5     144602443          es             0                   Santo domingo
# 6     212958140          es             1                       Argentina
# 7     278082770          es             0                             NaN
# 8     367651000          it             0                             NaN
# 9     599789901          ar             0                             NaN
# 10     10935572          en             1                             NaN
# 11     16119337          en             0                             NaN
# 12     16753788          en             0                             NaN
# 13     17640121          es             0                             NaN
# 14     17656600          en             9             Manhattan Beach, CA
# 15     19230427          en             0                           Ewell
# 16     19951698          en             0                             NaN
# 17     20726266          en             0                             NaN
# 18     20731719          en             0                             NaN
# 19     21196037          en             3           senawang, seremban ^^
# 20     21365952          en             0                             NaN
# 21     21375100          en             5                            Indy
# 22     21706899          en             0                             NaN
# 23     21972434          en             0                             NaN
# 24     25836383          en             9                     Connecticut
# 25     26778002          en             0                              FL
# 26     27662686          en             0                             NaN
# 27     28222509          en             0                             NaN
# 28     28265406          en             0                             NaN
# 29     28843786          en             0                     New Zealand
# ..          ...    ...  ...           ...                             ...
# 815   611238815          es             0                             NaN
# 816   611817370          es             0         San Pedro Sula Honduras
# 817   626820204          es             0                          mexico
# 818   630700348          es             0                           chile
# 819   635863952          fr             0                             NaN
# 820   717691526          es             0                             NaN
# 821   735242102          fr             0                        Montréal
# 822   759191942          en             0                             NaN
# 823   764770615          es             0                             NaN
# 824   794003875          es             0                             NaN
# 825   837889771          en             0                   New York City
# 826   845770021          en             0                             NaN
# 827   858707286          es             0                             NaN
# 828   869150966          en            32         Screaming at my beagles
# 829   909766628          es             0                             NaN
# 830   921913526          en             0                             USA
# 831   936112358          en             0                             NaN
# 832   951793016          es             0   En las nubes por este yerbón.
# 833   966110664          fr             0                             NaN
# 834   973256785          en             0                             NaN
# 835   989855300          es             0                   españa/madrid
# 836  1013213588          en             0                             NaN
# 837  1017855660          tr             0                             NaN
# 838  1023549769          en             0                              ty
# 839  1030686715          ko             0                             NaN
# 840  1098285654          ko             0                             NaN
# 841  1122936860          ko             0                             NaN
# 842  1129397028          en             0                             NaN
# 843  1151673038          fr             0                             NaN
# 844  1281271908          en             1                             NaN
#
#                      name      screen_name status  statuses_count  \
# 0                 YI YUAN        yi_twitts                     29
# 1          Marcos Perez C      marcos_peca                   1408
# 2           curti lorenzo     curtilorenzo                     39
# 3    ruben dario toscano        gatito2710                     59
# 4            Malek Khalaf      MalekKhalaf                    987
# 5     ruthyohannadelarosa      ruthyohanna                    286
# 6    Julieta Analia Perez          July_pz                     45
# 7        carlosjaviervega           bevega                     72
# 8        Giampaolo Taddei         giatadde                      1
# 9           Ahmed Mohamed        212Amhemd                      0
# 10          clareanderson       clarebear4                    557
# 11              protektor        protektor                    383
# 12                emsykes          emsykes                     30
# 13               litium54         litium54                     20
# 14       Dick Hillenbrand        rdhoosier                    307
# 15         ruth woolnough             ruwo                     96
# 16                  larry       gopher2000                    215
# 17    BibianaOrdensVieira  BibianaOrdensVi                      0
# 18            Chris Smith    chrissmithy76                    441
# 19             lisa ariff       lisa_ariff                     78
# 20                   shaw         mugenvic                      0
# 21            Sean Bolduc           seve_b                    221
# 22            Bob Dickson           BobD32                      1
# 23      Jerry Allen Moore        JaMMaNIII                      0
# 24            Jeanne Prom       jeanneprom                    647
# 25                      M      buryourself                   1513
# 26     erica hartenstein          gooseboo                     54
# 27            Corby Clark       Corbdizzle                      0
# 28     Jerri Lynn Rudesil           Jrude1                      0
# 29           Liam Perrell      liamperrell                      7
# ..                    ...              ...    ...             ...
# 815       heidy rodriguez  heidyro83649000                     29
# 816  karolina  hernandez   karolynhernand6                    106
# 817  esmeralda rodriguez   esmeral46813479                      3
# 818      elizabeth lagos   elizabethlagos6                      5
# 819              KS Style         style_ks                      0
# 820          luis ramirez         LdMackma                     71
# 821     Nathalie Peterson     NathPeterson                     18
# 822       Dace McLellan'e    mclellan_dace                      5
# 823         diego vasquez        OnixDiego                      6
# 824  José Eduardo Sarango    Joseeduardosn                      8
# 825        Jhuanna Soller        jhuannass                    244
# 826                   hey    lolipoppnit09                     11
# 827              clauchon        clauchonn                     24
# 828       Andrew Sullivan       SullyPanic                     77
# 829         sergio lucena    manguelracing                      2
# 830           Peggy Liddy       PeggyLiddy                      7
# 831       Joseph Bwambale          bjossey                      1
# 832      Smoke and smile.    mentecreadora                     55
# 833                SLAOUI      archislaoui                     39
# 834         chris siderio     chrissiderio                      0
# 835       claudiu marian    claudiuspataru                      4
# 836   Abdulrahman Elmegbl         AElmegbl                      0
# 837           Burhan inal      Burhaninal1                      1
# 838          justin ennis     SaturnBuster                      9
# 839                   채효주           mi3340                     10
# 840                    K.          k_ksaid                      1
# 841                Nick.J     Nick_DoubleJ                      6
# 842                carine    tweetyseventy                      1
# 843                Dennez    FlorianDennez                      5
# 844  I Respect the queen!       SearsTammy                    207
#
#                                         url  verified
# 0                    http://www.jycondo.com       NaN
# 1                                       NaN       NaN
# 2               http://www.valcavargna.com/       NaN
# 3                                       NaN       NaN
# 4    http://www.facebook.com/Malek.AlBalawi       NaN
# 5                                       NaN       NaN
# 6                                       NaN       NaN
# 7                                       NaN       NaN
# 8                                       NaN       NaN
# 9                                       NaN       NaN
# 10                                      NaN       NaN
# 11                                      NaN       NaN
# 12                                      NaN       NaN
# 13                                      NaN       NaN
# 14     http://www.heroesandvillains-ent.com       NaN
# 15                                      NaN       NaN
# 16                   http://t.co/5tJyTXnnvU       NaN
# 17                                      NaN       NaN
# 18                                      NaN       NaN
# 19                  http://www.facebook.com       NaN
# 20                                      NaN       NaN
# 21                                      NaN       NaN
# 22                                      NaN       NaN
# 23                                      NaN       NaN
# 24                     http://t.co/5XqgCKvi       NaN
# 25      http://www.ReverbNation.com/Minotti       NaN
# 26                                      NaN       NaN
# 27                                      NaN       NaN
# 28                                      NaN       NaN
# 29                                      NaN       NaN
# ..                                      ...       ...
# 815                                     NaN       NaN
# 816                                     NaN       NaN
# 817                                     NaN       NaN
# 818                                     NaN       NaN
# 819                                     NaN       NaN
# 820                                     NaN       NaN
# 821                                     NaN       NaN
# 822                                     NaN       NaN
# 823                                     NaN       NaN
# 824                                     NaN       NaN
# 825                                     NaN       NaN
# 826                                     NaN       NaN
# 827                                     NaN       NaN
# 828                http://wakethefuckup.com       NaN
# 829                                     NaN       NaN
# 830                                     NaN       NaN
# 831                                     NaN       NaN
# 832                                     NaN       NaN
# 833                                     NaN       NaN
# 834                                     NaN       NaN
# 835                                     NaN       NaN
# 836                                     NaN       NaN
# 837                                     NaN       NaN
# 838                                     NaN       NaN
# 839                                     NaN       NaN
# 840                                     NaN       NaN
# 841                                     NaN       NaN
# 842                                     NaN       NaN
# 843                                     NaN       NaN
# 844                                     NaN       NaN
#
# [845 rows x 20 columns]

# %%
fake_users.dtypes
# Out:
# bot                       object
# created_at                object
# default_profile          float64
# default_profile_image    float64
# description               object
# favourites_count           int64
# followers_count            int64
# friends_count              int64
# has_extended_profile      object
# id                         int64
# id_str                    object
# lang                      object
# listed_count               int64
# location                  object
# name                      object
# screen_name               object
# status                    object
# statuses_count             int64
# url                       object
# verified                 float64
# dtype: object

# %%
fake_users.isna().sum()
# Out:
# bot                        0
# created_at                 0
# default_profile          311
# default_profile_image    843
# description              627
# favourites_count           0
# followers_count            0
# friends_count              0
# has_extended_profile       0
# id                         0
# id_str                     0
# lang                       0
# listed_count               0
# location                 500
# name                       0
# screen_name                0
# status                     0
# statuses_count             0
# url                      744
# verified                 845
# dtype: int64

# %%
fake_users.bot = 1

# %%
fake_users.default_profile = fake_users.default_profile.fillna(0)
fake_users.default_profile = fake_users.default_profile.astype(int)

# %%
fake_users.default_profile.value_counts()
# Out:
# 1    534
# 0    311
# Name: default_profile, dtype: int64

# %%
fake_users.default_profile_image = fake_users.default_profile_image.fillna(0)
fake_users.default_profile_image = fake_users.default_profile_image.astype(int)

fake_users.default_profile_image.value_counts()
# Out:
# 0    843
# 1      2
# Name: default_profile_image, dtype: int64

# %%
fake_users.description = fake_users.description.fillna('No description')
fake_users.location = fake_users.location.fillna('No location')

# %%
fake_users.url = fake_users.url.fillna('No url')

# %%
fake_users.to_csv('fake_users_.csv', encoding='utf-8', index=False)

# %%
# second fake dataset to balance samples 
# This dataset is from Contact: http://mib.projects.iit.cnr.it/dataset.html  crn 2017 dataset
# more data - https://botometer.iuni.iu.edu/bot-repository/datasets.html

twt_fake_2017 = pd.read_csv('/Users/pbiswas/Desktop/cresci-2017.csv/datasets_full.csv/fake_followers.csv/users.csv')

twt_fake_2017.head()
# Out:
#           id                  name   screen_name  statuses_count  \
# 0   80479674               YI YUAN     yi_twitts              29
# 1   82487179        Marcos Perez C   marcos_peca            1408
# 2  105830531         curti lorenzo  curtilorenzo              39
# 3  114488344  ruben dario toscano     gatito2710              59
# 4  123222267          Malek Khalaf   MalekKhalaf             987
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0               19            255                 1             0
# 1              208            866               138             0
# 2               59            962                 8             0
# 3                7             49                 4             0
# 4               60            521                61             1
#
#                        created_at                                     url  \
# 0  Wed Oct 07 03:19:21 +0000 2009                  http://www.jycondo.com
# 1  Wed Oct 14 23:40:17 +0000 2009                                     NaN
# 2  Sun Jan 17 16:46:52 +0000 2010             http://www.valcavargna.com/
# 3  Mon Feb 15 15:49:58 +0000 2010                                     NaN
# 4  Mon Mar 15 11:38:55 +0000 2010  http://www.facebook.com/Malek.AlBalawi
#
#           ...          utc_offset is_translator follow_request_sent  \
# 0         ...            -18000.0           NaN                 NaN
# 1         ...            -21600.0           NaN                 NaN
# 2         ...                 0.0           NaN                 NaN
# 3         ...            -18000.0           NaN                 NaN
# 4         ...             10800.0           NaN                 NaN
#
#    protected  verified  notifications  \
# 0        NaN       NaN            NaN
# 1        NaN       NaN            NaN
# 2        NaN       NaN            NaN
# 3        NaN       NaN            NaN
# 4        NaN       NaN            NaN
#
#                                          description contributors_enabled  \
# 0                                 real estate sales                   NaN
# 1                                                NaN                  NaN
# 2  le corna del capro scappato dal gregge s'infil...                  NaN
# 3                                                NaN                  NaN
# 4  MA student at JU, Interested in Juventus,Italy...                  NaN
#
#    following              updated
# 0        NaN  2013-06-12 18:38:35
# 1        NaN  2013-06-12 18:38:35
# 2        NaN  2013-06-12 18:38:35
# 3        NaN  2013-06-12 18:38:35
# 4        NaN  2013-06-11 17:39:44
#
# [5 rows x 38 columns]

# %%
# matching with existing dataset

#def createOutput(data):
header = ['bot', 'created_at', 'default_profile', 'default_profile_image',
       'description', 'favourites_count', 'followers_count', 'friends_count',
       'has_extended_profile', 'id', 'id_str', 'lang', 'listed_count',
       'location', 'name', 'screen_name', 'status', 'statuses_count', 'url',
       'verified']
fake_users_2017 = pd.DataFrame(columns=header)
for key in header:
    if key not in twt_fake_2017.columns:
        fake_users_2017[key] = ""
    else:
        fake_users_2017[key] = twt_fake_2017[key]

#df = pd.DataFrame(d, columns= header, index=np.arange(1))
# df['bot'] = isbot
#return df

# %%
fake_users_2017
# Out:
#       bot                      created_at  default_profile  \
# 0     NaN  Wed Oct 07 03:19:21 +0000 2009              NaN
# 1     NaN  Wed Oct 14 23:40:17 +0000 2009              NaN
# 2     NaN  Sun Jan 17 16:46:52 +0000 2010              NaN
# 3     NaN  Mon Feb 15 15:49:58 +0000 2010              1.0
# 4     NaN  Mon Mar 15 11:38:55 +0000 2010              NaN
# 5     NaN  Sun May 16 19:51:50 +0000 2010              1.0
# 6     NaN  Sun Nov 07 15:13:37 +0000 2010              1.0
# 7     NaN  Wed Apr 06 15:35:32 +0000 2011              1.0
# 8     NaN  Sun Sep 04 09:54:29 +0000 2011              1.0
# 9     NaN  Thu Sep 08 13:20:35 +0000 2011              NaN
# 10    NaN  Tue Jun 05 01:12:01 +0000 2012              1.0
# 11    NaN  Fri Dec 07 13:57:04 +0000 2007              NaN
# 12    NaN  Wed Sep 03 20:42:11 +0000 2008              1.0
# 13    NaN  Wed Oct 15 03:31:07 +0000 2008              1.0
# 14    NaN  Wed Nov 26 02:48:55 +0000 2008              NaN
# 15    NaN  Wed Nov 26 18:59:35 +0000 2008              NaN
# 16    NaN  Tue Jan 20 10:53:18 +0000 2009              1.0
# 17    NaN  Tue Feb 03 03:26:53 +0000 2009              1.0
# 18    NaN  Thu Feb 12 22:24:36 +0000 2009              1.0
# 19    NaN  Thu Feb 12 23:32:13 +0000 2009              NaN
# 20    NaN  Wed Feb 18 13:40:55 +0000 2009              NaN
# 21    NaN  Fri Feb 20 02:26:24 +0000 2009              1.0
# 22    NaN  Fri Feb 20 04:51:31 +0000 2009              NaN
# 23    NaN  Mon Feb 23 23:25:12 +0000 2009              1.0
# 24    NaN  Thu Feb 26 04:53:01 +0000 2009              1.0
# 25    NaN  Sun Mar 22 16:10:49 +0000 2009              NaN
# 26    NaN  Thu Mar 26 15:50:25 +0000 2009              NaN
# 27    NaN  Mon Mar 30 15:44:58 +0000 2009              1.0
# 28    NaN  Wed Apr 01 23:12:44 +0000 2009              1.0
# 29    NaN  Thu Apr 02 02:49:56 +0000 2009              1.0
# ...   ...                             ...              ...
# 3321  NaN  Fri Apr 26 03:01:40 +0000 2013              1.0
# 3322  NaN  Fri Apr 26 04:29:24 +0000 2013              1.0
# 3323  NaN  Fri Apr 26 04:36:10 +0000 2013              1.0
# 3324  NaN  Fri Apr 26 06:01:54 +0000 2013              1.0
# 3325  NaN  Fri Apr 26 06:55:21 +0000 2013              1.0
# 3326  NaN  Fri Apr 26 08:15:07 +0000 2013              1.0
# 3327  NaN  Fri Apr 26 09:19:40 +0000 2013              1.0
# 3328  NaN  Fri Apr 26 09:40:43 +0000 2013              1.0
# 3329  NaN  Fri Apr 26 10:48:31 +0000 2013              1.0
# 3330  NaN  Fri Apr 26 11:55:55 +0000 2013              1.0
# 3331  NaN  Fri Apr 26 13:20:56 +0000 2013              1.0
# 3332  NaN  Fri Apr 26 17:12:08 +0000 2013              1.0
# 3333  NaN  Sat Apr 27 06:36:03 +0000 2013              1.0
# 3334  NaN  Sat Apr 27 18:53:21 +0000 2013              1.0
# 3335  NaN  Sat Apr 27 19:30:24 +0000 2013              1.0
# 3336  NaN  Sun Apr 28 05:21:14 +0000 2013              1.0
# 3337  NaN  Sun Apr 28 09:20:00 +0000 2013              1.0
# 3338  NaN  Sun Apr 28 09:26:04 +0000 2013              1.0
# 3339  NaN  Sun Apr 28 10:22:11 +0000 2013              1.0
# 3340  NaN  Sun Apr 28 17:01:13 +0000 2013              1.0
# 3341  NaN  Sun Apr 28 16:57:51 +0000 2013              1.0
# 3342  NaN  Sun Apr 28 19:16:27 +0000 2013              1.0
# 3343  NaN  Sun Apr 28 22:04:02 +0000 2013              1.0
# 3344  NaN  Mon Apr 29 06:39:34 +0000 2013              1.0
# 3345  NaN  Tue Apr 30 07:11:17 +0000 2013              1.0
# 3346  NaN  Tue Apr 30 08:23:57 +0000 2013              1.0
# 3347  NaN  Tue Apr 30 08:34:49 +0000 2013              1.0
# 3348  NaN  Tue Apr 30 09:21:12 +0000 2013              1.0
# 3349  NaN  Tue Apr 30 11:25:11 +0000 2013              1.0
# 3350  NaN  Tue Apr 30 12:47:51 +0000 2013              1.0
#
#       default_profile_image  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ...                     ...
# 3321                    NaN
# 3322                    NaN
# 3323                    NaN
# 3324                    NaN
# 3325                    NaN
# 3326                    NaN
# 3327                    NaN
# 3328                    NaN
# 3329                    NaN
# 3330                    NaN
# 3331                    NaN
# 3332                    NaN
# 3333                    NaN
# 3334                    NaN
# 3335                    NaN
# 3336                    NaN
# 3337                    NaN
# 3338                    NaN
# 3339                    NaN
# 3340                    NaN
# 3341                    NaN
# 3342                    NaN
# 3343                    NaN
# 3344                    NaN
# 3345                    NaN
# 3346                    NaN
# 3347                    NaN
# 3348                    NaN
# 3349                    NaN
# 3350                    NaN
#
#                                             description  favourites_count  \
# 0                                    real estate sales                  1
# 1                                                   NaN               138
# 2     le corna del capro scappato dal gregge s'infil...                 8
# 3                                                   NaN                 4
# 4     MA student at JU, Interested in Juventus,Italy...                61
# 5      Con Dios no necesito nada mas el es mi fortaleza                 3
# 6                                                   NaN                 0
# 7                                                   NaN                 0
# 8                                                   NaN                 0
# 9                                                   NaN                16
# 10                                                  NaN                 0
# 11                                                  NaN                 7
# 12                                                  NaN                10
# 13                                                  NaN                 0
# 14                                                  NaN                 0
# 15    Principal/Investor - Hillenbrand Capital Partn...                92
# 16    Live life to the full never regret the past bu...                 1
# 17                                                  NaN                13
# 18                                                  NaN                 0
# 19                                                  NaN                 0
# 20                                                  NaN                 0
# 21                                                  NaN                 0
# 22                 236 years...Well, we had a good run.                 7
# 23                                                  NaN                 0
# 24                                                  NaN                 0
# 25    Spirited Artist, Passionate Life Empowerment C...                 6
# 26    Artist,Songwriter,Producer buryourself@gmail.c...                 2
# 27                                                  NaN                 3
# 28                                                  NaN                 0
# 29                                                  NaN                 0
# ...                                                 ...               ...
# 3321                                                NaN                 0
# 3322  Where Torque and Horsepowr Meet, we are a perf...                 0
# 3323  Enjoy Sharing with each other your Tips, Jobs,...                 0
# 3324                                                NaN                 0
# 3325                                                NaN                 0
# 3326  Spreading the power of music through guitars i...                 0
# 3327  cul n sexy buh hot temprd teamfolloback ifollo...                 0
# 3328  Hit That Follow Button & Find Out ! TeamFollow...                 0
# 3329                                                NaN                 0
# 3330     The officia twitter of the unofficial blog....                 0
# 3331                            I love he cmpetition...                 0
# 3332                                                NaN                 0
# 3333   Pedro Lanza eu te amo mais que tudo nessemundo!♥                 0
# 3334                                                NaN                 0
# 3335  Gt a lot of love for three boys named Dan Ferr...                 0
# 3336                                                NaN                 0
# 3337  TeamBrownskin TeamGemini TeamBOOGIE TeamFollow...                 0
# 3338                                                NaN                 0
# 3339                                                NaN                 0
# 3340  Great Clients, Great Websites. Web design, dev...                 0
# 3341  The Oficial witter Page of FollowBackTour *  T...                 0
# 3342                                                NaN                 0
# 3343  | TeamDarkSkinn , 5'9 , Tha Name iss BiiG RICH...                 0
# 3344  Heling people find a healthier body onelb at a...                 0
# 3345                                                NaN                 0
# 3346  I have been in business onlin and offline for ...                 0
# 3347                                                NaN                 0
# 3348                                                NaN                 0
# 3349                                                NaN                 0
# 3350  Hello!im a BELIEBER! IM A HUGE FAN OF JUSTIN B...                 0
#
#       followers_count  friends_count has_extended_profile          id id_str  \
# 0                  19            255                         80479674
# 1                 208            866                         82487179
# 2                  59            962                        105830531
# 3                   7             49                        114488344
# 4                  60            521                        123222267
# 5                 141           1075                        144602443
# 6                  16            342                        212958140
# 7                  14            287                        278082770
# 8                   0            122                        367651000
# 9                   4            588                        370098498
# 10                  4            228                        599789901
# 11                171           1398                         10935572
# 12                  9            564                         16119337
# 13                 91            527                         16753788
# 14                 17            361                         17640121
# 15                583            836                         17656600
# 16                 13            466                         19230427
# 17                 63            901                         19951698
# 18                  6            599                         20726266
# 19                 18           1009                         20731719
# 20                130            484                         21196037
# 21                  9            595                         21365952
# 22                271           1199                         21375100
# 23                  5            549                         21706899
# 24                 19           1031                         21972434
# 25                547           1286                         25836383
# 26                492           2004                         26778002
# 27                 28            577                         27662686
# 28                  3            475                         28222509
# 29                 10            559                         28265406
# ...               ...            ...                  ...         ...    ...
# 3321                0             17                       1380948325
# 3322                1             21                       1381040010
# 3323                0             20                       1381069658
# 3324                1              8                       1381167558
# 3325                0             15                       1381246512
# 3326                0             17                       1381363692
# 3327                0             16                       1381459980
# 3328                2             19                       1381512248
# 3329                2             15                       1381607736
# 3330                1             17                       1381744988
# 3331                2             20                       1381913143
# 3332                0             15                       1382419244
# 3333                1             20                       1383712140
# 3334                1             14                       1385228084
# 3335                0             18                       1385297372
# 3336                2             15                       1386172154
# 3337                2             15                       1386519432
# 3338                1             18                       1386549638
# 3339                1             22                       1386619668
# 3340                0             18                       1387393236
# 3341                0             22                       1387417639
# 3342                0             24                       1387702238
# 3343                1             12                       1388028872
# 3344                1             21                       1388819528
# 3345                1             19                       1391378610
# 3346                0             17                       1391497074
# 3347                1             17                       1391544607
# 3348                0             15                       1391622127
# 3349                0             16                       1391832212
# 3350                0             17                       1391998039
#
#      lang  listed_count                        location                  name  \
# 0      en             0                         toronto               YI YUAN
# 1      es             0                             NaN        Marcos Perez C
# 2      it             0  San Bartolomeo Val Cavargna CO         curti lorenzo
# 3      es             0                            peru  ruben dario toscano
# 4      en             1             31.975193,35.920294          Malek Khalaf
# 5      es             0                   Santo domingo   ruthyohannadelarosa
# 6      es             1                       Argentina  Julieta Analia Perez
# 7      es             0                             NaN      carlosjaviervega
# 8      it             0                             NaN      Giampaolo Taddei
# 9      en             0                             NaN          pirfectmoses
# 10     ar             0                             NaN         Ahmed Mohamed
# 11     en             1                             NaN         clareanderson
# 12     en             0                             NaN             protektor
# 13     en             0                             NaN               emsykes
# 14     es             0                             NaN              litium54
# 15     en             9             Manhattan Beach, CA      Dick Hillenbrand
# 16     en             0                           Ewell        ruth woolnough
# 17     en             0                             NaN                 larry
# 18     en             0                             NaN   BibianaOrdensVieira
# 19     en             0                             NaN           Chris Smith
# 20     en             3           senawang, seremban ^^            lisa ariff
# 21     en             0                             NaN                  shaw
# 22     en             5                            Indy           Sean Bolduc
# 23     en             0                             NaN           Bob Dickson
# 24     en             0                             NaN     Jerry Allen Moore
# 25     en             9                     Connecticut           Jeanne Prom
# 26     en             0                              FL                     M
# 27     en             0                             NaN    erica hartenstein
# 28     en             0                             NaN           Corby Clark
# 29     en             0                             NaN    Jerri Lynn Rudesil
# ...   ...           ...                             ...                   ...
# 3321   en             0                           Bogor      Dolores Mckenzie
# 3322   en             0       ÜT: 48.483436,-123.385259        Louann Carroll
# 3323   en             0                             NaN    Anneliese Franklin
# 3324   en             0                             NaN           Ming Meyers
# 3325   en             0            Republica Dominicana   Estrella Valenzuela
# 3326   en             0                         Florida          Jewel Bailey
# 3327   en             0                         nigeria          Kaley Romero
# 3328   en             0                    CandyLand :P      Maynard Anderson
# 3329   en             0                  São Paulo - SP      Adelaide Dejesus
# 3330   en             0         Everywhere U want to be             Zina Cote
# 3331   en             0                 East Coast, USA         Ira Rasmussen
# 3332   en             0                 In my own world          Eulah Burton
# 3333   en             0                             NaN      Chiquita Rosario
# 3334   en             0                  washington, pa         Hyo Zimmerman
# 3335   en             0                             NaN        Yolanda Hooper
# 3336   en             0                             NaN            Leesa Hood
# 3337   en             0               HOUSTATLANTAVEGAS         Lorina Macias
# 3338   en             0                             NaN      Jacquelyn Dunlap
# 3339   en             0                             NaN         Darryl Hansen
# 3340   en             0             Victoria, BC Canada        Lillie Leonard
# 3341   en             0                Around The World       Kenyetta Sutton
# 3342   en             0                             NaN       Theodore Harmon
# 3343   en             0               Las Vages, Navada         Delmer Morris
# 3344   en             0                      London, UK         Pearle Atkins
# 3345   en             0                  Cleveland,Ohio        Delila Merritt
# 3346   en             0                      Murphy, NC           Verda Marks
# 3347   en             0                             NaN       Danial Campbell
# 3348   en             0                      Rome,Italy          Maudie Meyer
# 3349   en             0                             NaN       Harriett Harvey
# 3350   en             0                             NaN       Gillian Wheeler
#
#           screen_name status  statuses_count  \
# 0           yi_twitts                     29
# 1         marcos_peca                   1408
# 2        curtilorenzo                     39
# 3          gatito2710                     59
# 4         MalekKhalaf                    987
# 5         ruthyohanna                    286
# 6             July_pz                     45
# 7              bevega                     72
# 8            giatadde                      1
# 9        pirfectmoses                     24
# 10          212Amhemd                      0
# 11         clarebear4                    557
# 12          protektor                    383
# 13            emsykes                     30
# 14           litium54                     20
# 15          rdhoosier                    307
# 16               ruwo                     96
# 17         gopher2000                    215
# 18    BibianaOrdensVi                      0
# 19      chrissmithy76                    441
# 20         lisa_ariff                     78
# 21           mugenvic                      0
# 22             seve_b                    221
# 23             BobD32                      1
# 24          JaMMaNIII                      0
# 25         jeanneprom                    647
# 26        buryourself                   1513
# 27           gooseboo                     54
# 28         Corbdizzle                      0
# 29             Jrude1                      0
# ...               ...    ...             ...
# 3321  DoloresMckenz13                      0
# 3322   LouannCarroll3                      2
# 3323  AnnelieseFrankl                      0
# 3324       MingMeyers                      2
# 3325  EstrellaValenz6                      3
# 3326    JewelBailey14                      1
# 3327     KaleyRomero1                      3
# 3328  MaynardAnderso2                      1
# 3329  AdelaideDejesu2                      2
# 3330         ZinaCote                      1
# 3331     IraRasmussen                      1
# 3332     EulahBurton1                      2
# 3333  ChiquitaRosari2                      2
# 3334     HyoZimmerman                      2
# 3335   YolandaHooper7                      1
# 3336        LeesaHood                      1
# 3337     LorinaMacias                      2
# 3338  JacquelynDunl16                      2
# 3339    DarrylHansen3                      3
# 3340  LillieLeonard12                      2
# 3341   KenyettaSutton                      2
# 3342  TheodoreHarmon2                      2
# 3343    DelmerMorris1                      1
# 3344    PearleAtkins1                      1
# 3345   DelilaMerritt1                      2
# 3346      VerdaMarks1                      1
# 3347  DanialCampbell2                      0
# 3348     MaudieMeyer1                      2
# 3349  HarriettHarvey9                      2
# 3350  GillianWheeler3                      0
#
#                                          url  verified
# 0                     http://www.jycondo.com       NaN
# 1                                        NaN       NaN
# 2                http://www.valcavargna.com/       NaN
# 3                                        NaN       NaN
# 4     http://www.facebook.com/Malek.AlBalawi       NaN
# 5                                        NaN       NaN
# 6                                        NaN       NaN
# 7                                        NaN       NaN
# 8                                        NaN       NaN
# 9                                        NaN       NaN
# 10                                       NaN       NaN
# 11                                       NaN       NaN
# 12                                       NaN       NaN
# 13                                       NaN       NaN
# 14                                       NaN       NaN
# 15      http://www.heroesandvillains-ent.com       NaN
# 16                                       NaN       NaN
# 17                    http://t.co/5tJyTXnnvU       NaN
# 18                                       NaN       NaN
# 19                                       NaN       NaN
# 20                   http://www.facebook.com       NaN
# 21                                       NaN       NaN
# 22                                       NaN       NaN
# 23                                       NaN       NaN
# 24                                       NaN       NaN
# 25                      http://t.co/5XqgCKvi       NaN
# 26       http://www.ReverbNation.com/Minotti       NaN
# 27                                       NaN       NaN
# 28                                       NaN       NaN
# 29                                       NaN       NaN
# ...                                      ...       ...
# 3321                                     NaN       NaN
# 3322                                     NaN       NaN
# 3323                                     NaN       NaN
# 3324                                     NaN       NaN
# 3325                                     NaN       NaN
# 3326                                     NaN       NaN
# 3327                                     NaN       NaN
# 3328                                     NaN       NaN
# 3329                                     NaN       NaN
# 3330                                     NaN       NaN
# 3331                                     NaN       NaN
# 3332                                     NaN       NaN
# 3333                                     NaN       NaN
# 3334                                     NaN       NaN
# 3335                                     NaN       NaN
# 3336                                     NaN       NaN
# 3337                                     NaN       NaN
# 3338                                     NaN       NaN
# 3339                                     NaN       NaN
# 3340                                     NaN       NaN
# 3341                                     NaN       NaN
# 3342                                     NaN       NaN
# 3343                                     NaN       NaN
# 3344                                     NaN       NaN
# 3345                                     NaN       NaN
# 3346                                     NaN       NaN
# 3347                                     NaN       NaN
# 3348                                     NaN       NaN
# 3349                                     NaN       NaN
# 3350                                     NaN       NaN
#
# [3351 rows x 20 columns]

# %%
fake_users_2017.bot = 1

fake_users_2017.default_profile = fake_users_2017.default_profile.fillna(0).astype(int)
fake_users_2017.default_profile = fake_users_2017.default_profile

fake_users_2017.default_profile_image = fake_users_2017.default_profile_image.fillna(0)
fake_users_2017.default_profile_image = fake_users_2017.default_profile_image.astype(int)
fake_users_2017.description = fake_users_2017.description.fillna('No description')
fake_users_2017.location = fake_users_2017.location.fillna('No location')
fake_users_2017.url = fake_users_2017.url.fillna('No url')

# %%
fake_users_2017.isna().sum()
# Out:
# bot                         0
# created_at                  0
# default_profile             0
# default_profile_image       0
# description                 0
# favourites_count            0
# followers_count             0
# friends_count               0
# has_extended_profile        0
# id                          0
# id_str                      0
# lang                        0
# listed_count                0
# location                    0
# name                        0
# screen_name                 0
# status                      0
# statuses_count              0
# url                         0
# verified                 3351
# dtype: int64

# %%
fake_users_2017.to_csv('fake_users_2.csv', encoding='utf-8', index=False)

# %%
for user in users:
    print(user.name)
    
    for tweet in tweepy.Cursor(api.search,q="#unitedAIRLINES",count=100,
                           lang="en",
                           since="2017-04-03").items():
    print (tweet.created_at, tweet.text)
# Out:
# Tara Dublin #IVoted 🌊
# Kavin #IVoted
# #iVoted
# Tim “#IVoted - Have You Voted?” Bond
# Nadine van der Velde
# #IVoted
# Rafe 🇺🇸 #VOTE! Nov 6th
# Samira Tu'Ala #IVoted
# r🎃gue1 #IVoted
# MAGA! 1 DAY @ A TIME
# fl_brooke #gobolts #IVoted
# #IVoted! Shad Clark
# Rob Dexter
# Hispanic! At The Disco #ivoted
# I Voted Remain 🇪🇺 #StopBrexit #FBPE #PeoplesVote
# iVoted
# I Voted
# Sudie
# Nigel Huckle
# Hope Made Human

# %%
real_users = []
for user in tweepy.Cursor(api.get_user, screen_name="verified").items():  #'friends are the accounts that @verified follows and are verified'
    verified_screen_names.append(user.screen_name)
    print('friend: ' + user.screen_name, user.verified)
