# %% [markdown]
# ## Bootcamp Unit1 Lesson 2 Intermediate Visualization Drills
#
# ### Drills
# Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#
# - Choose one variable and plot that variable four different ways.
# - Choose two continuous variables, and plot them three different ways.
# - Choose one continuous variable and one categorical variable, and plot them six different ways.
#
# Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.
#
# ### Challenge
# As an optional challenge, find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#
# - Probability distributions
# - Bivariate relationships
# - Whether the distributions or the relationships vary across groups
#
# Accompany your plot with a written description of what you see.

# %% [markdown]
# # Drills

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#import certifi
# %matplotlib inline

# %%
# Loading an example dataset provided by the seaborn package.
iris = sns.load_dataset("iris") # running /Applications/Python\ 3.6/Install\ Certificates.command fixed the URLError: ssl.c:833)
print(iris.head(20))
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
#Changing the string to numerical/categorical variable. 
#specis_num = []
#
#for row in iris['species']:
#    if row == "setosa":
#        specis_num.append(1)
#    elif row == "virginica":
#        specis_num.append(2)
#    elif row == "versicolor":
#        specis_num.append(3)
#
#iris['species_num'] = specis_num

# %%
#creating 
setosa_petal_len = iris.loc[iris.species == "setosa", 'petal_length']
setosa_petal_wid = iris.loc[iris.species == "setosa", 'petal_width']

# %% [markdown]
# #### Choose one variable and plot that variable four different ways.

# %%
#creating histogram of petal length

plt.hist(setosa_petal_len)
plt.legend(['Setosa petal length'])
plt.show()

# %%
plt.scatter(setosa_petal_len, setosa_petal_wid)
plt.xlabel('setosa petal length')
plt.ylabel('setosa petal width')
plt.show()

# %%
plt.boxplot(setosa_petal_len)
plt.show()

# %%
plt.plot(setosa_petal_len)
plt.show()

# %%
#trying the same with seaborn --
sns.set(style='ticks')
g = sns.FacetGrid(iris, col="species")
g.map(plt.hist, "petal_length")
plt.show()

# %%
ax = sns.boxplot(x='species',y='petal_width',data=iris)  
plt.title('Petal lengths by iris species')
sns.despine(offset=10, trim=True)
ax.set(xlabel='', ylabel='Petal width')

plt.show()

# %%
ax = sns.barplot(x='species',y='petal_width',data=iris)  
plt.title('Petal lengths by iris species')
sns.despine(offset=10, trim=True)
ax.set(xlabel='', ylabel='Petal width')

plt.show()

# %%
sns.stripplot(x="species", y="petal_length", jitter =True, data=iris)

# %%
sns.swarmplot(x="species", y="petal_length",  data=iris)

# %%
sns.violinplot(x="species", y="petal_length",  data=iris)

# %%
sns.distplot(iris[iris['species'] == "setosa"].petal_length)
sns.distplot(iris[iris['species'] == "virginica"].petal_length)
sns.distplot(iris[iris['species'] == "versicolor"].petal_length)
plt.legend(['setosa', 'virginica', 'versicolor'])
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### Choose two continuous variables, and plot them three different ways.

# %%
sns.jointplot(x="petal_length", y='petal_width', data=iris)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="petal_length", y='petal_width', data=iris, kind="kde")

# %%
sns.factorplot(x="petal_length", y='petal_width', data=iris)

# %%
sns.pairplot(iris)

# %% [markdown]
# #### Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
titanic = sns.load_dataset("titanic") # running /Applications/Python\ 3.6/Install\ Certificates.command fixed the URLError: ssl.c:833)
print(titanic.head(20))
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
# Comparing groups using boxplots.
ax = sns.boxplot(x='sex',y='age',hue='sex',data=titanic)  
plt.title('age and sex distribution')
sns.despine(offset=10, trim=True)
ax.set(xlabel='', ylabel='age')
# Out:
# [Text(0,0.5,'age'), Text(0.5,0,'')]

# %%
# Setting the overall aesthetic.
sns.set(style="darkgrid")

g = sns.factorplot(x="sex", y="age", hue="alive", data=titanic,
                   size=6, kind="bar", palette="pastel", ci=95)
g.despine(left=True)
g.set_ylabels("Age")
g.set_xlabels("")
plt.title('Barplot: Post-event life count after by Age and Gender')
plt.show()

# %%
sns.set(style='dark')
g = sns.factorplot(x="sex", y="pclass", hue="alive", data=titanic, size=6, kind="point", palette="pastel", ci=95)

g.despine(left=True)
g.set_xlabels("")
g.set_ylabels("class")
plt.title("Pointplot: Alive by class and Gender")
plt.show()
